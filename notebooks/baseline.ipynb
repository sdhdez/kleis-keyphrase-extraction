# %%
from kleis.resources import dataset as kd
import pycrfsuite

# %%
default_corpus = kd.load_corpus()
default_corpus.load_train()
default_corpus.training(features_method="simple")

# %%
train = [{'tags': v['tags'], 'keyphrases': v['keyphrases']} for k,v in default_corpus.train.items()]

X_train = []
y_train = []
for element in train:
    tags = list(map(lambda t: [t[0], t[1], t[2], 'O'], element['tags']))
    for keyphrase in element['keyphrases'].values():
        # print(keyphrase)
        tokens_indices = keyphrase['tokens-indices']
        if len(tokens_indices) == 1:
            U = tokens_indices[0]
            tags[U][3] = 'U-KEYPHRASE'
        elif len(tokens_indices) > 1:
            B = tokens_indices[0]
            L = tokens_indices[-1]
            tags[B][3] = 'B-KEYPHRASE'
            tags[L][3] = 'L-KEYPHRASE'
            for x in tokens_indices[1:-1]:
                tags[x][3] = 'I-KEYPHRASE'
            
    features = [kd.simple_features(tag, i, len(tags), [], []) for i, tag in enumerate(tags)]
    labels = [tag[3] for i, tag in enumerate(tags)]
    X_train.append(features)
    y_train.append(labels)
    # print(labels)
    # print(features)
    # print(tags)
print(len(X_train), len(y_train))
# print(X_train[-1], y_train[-1])
# Out:
# 350 350

# %%
trainer = pycrfsuite.Trainer(verbose=False)
for xseq, yseq in zip(X_train, y_train):
    trainer.append(xseq, yseq)

# %%
trainer.set_params({
    'c1': 1.0,   # coefficient for L1 penalty
    'c2': 1e-3,  # coefficient for L2 penalty
    # 'max_iterations': 50,  # stop earlier
    # include transitions that are possible, but not observed
    'feature.possible_transitions': True
})

trainer.params()
# Out:
# ['feature.minfreq',
#  'feature.possible_states',
#  'feature.possible_transitions',
#  'c1',
#  'c2',
#  'max_iterations',
#  'num_memories',
#  'epsilon',
#  'period',
#  'delta',
#  'linesearch',
#  'max_linesearch']

# %%
model = 'baseline.semeval2017-task10.pycrfsuite'
if not kd.path_exists(model):
    trainer.train(model)

# %%
tagger = pycrfsuite.Tagger()
tagger.open('baseline.semeval2017-task10.pycrfsuite')

# %%
default_corpus.load_dev()

# %%
import os
output = 'output-baseline/dev/'
if not kd.path_exists(output):
    os.makedirs(output)
    
for i, (key, tmp_dataset) in enumerate(default_corpus.dev.items()):
    text = tmp_dataset["raw"]["txt"]
    tags = tmp_dataset["tags"]
    X_test = [kd.simple_features(tag, i, len(tags), [], []) for i, tag in enumerate(tags)]
    keyphrases_kleis = default_corpus.label_text(text)
    # print(tags)
    keyphrases = []
    keyphrases_labels = tagger.tag(X_test)
    tid = 0
    for token_index, label in enumerate(keyphrases_labels):
        if label == 'O':
            continue
        else:
            if label[:2] == 'U-':
                tid += 1
                keyphrase = None
                token_start = min(tags[token_index][2])
                token_end = max(tags[token_index][2])
                keyphrase = ("T%d" % tid, ("KEYPHRASE", (token_start, token_end)), text[token_start:token_end])
                keyphrases.append(keyphrase)
                
            if label[:2] == 'B-':
                tid += 1
                token_start = min(tags[token_index][2])
                token_end = max(tags[token_index][2])
                keyphrase = ("T%d" % tid, ("KEYPHRASE", (token_start, token_end)), text[token_start:token_end])
                
            if label[:2] == 'I-':
                token_end = max(tags[token_index][2])
                kp_id, (kp_label, (kp_start, _)), _ = keyphrase
                keyphrase = (kp_id, (kp_label, (kp_start, token_end)), text[kp_start:token_end])

            if label[:2] == 'L-':
                token_end = max(tags[token_index][2])
                kp_id, (kp_label, (kp_start, _)), _ = keyphrase
                keyphrases.append((kp_id, (kp_label, (kp_start, token_end)), text[kp_start:token_end]))
                keyphrase = None

    #print("\n".join([str(kp) for kp in keyphrases]))
    print("\n%d ----" % (i+1))
    print("\n  +++ CRF +++ \n")  
    print(kd.keyphrases2brat(keyphrases))
    print("\n  +++ KLEIS +++ \n")  
    print(kd.keyphrases2brat(keyphrases_kleis))
    print("\n  +++ RAW +++ \n") 
    print(tmp_dataset["raw"]["ann"])
    with open(output + key + ".ann", "w", encoding="utf-8") as fout:
        fout.write(kd.keyphrases2brat(keyphrases))
    with open(output + key + ".txt", "w", encoding="utf-8") as fout:
        fout.write(text)
    # print(keyphrases)
# Out:
# 1 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 18 21	PCM
# T2	KEYPHRASE 117 135	Mock up” PCM drums
# T3	KEYPHRASE 183 192	PCM drums
# T4	KEYPHRASE 214 244	mild steel paint cans and lids
# T5	KEYPHRASE 246 266	Fenton Packaging Ltd
# T6	KEYPHRASE 270 278	PVC bags
# T7	KEYPHRASE 301 323	identical PVC sheeting
# T8	KEYPHRASE 325 343	Romar Workwear Ltd
# T9	KEYPHRASE 351 379	metallic waste was simulated
# T10	KEYPHRASE 386 423	commercial grade 18/8 stainless steel
# T11	KEYPHRASE 425 473	aluminium and copper (Avus Metals & Plastics Ltd
# T12	KEYPHRASE 506 535	inorganic waste was simulated
# T13	KEYPHRASE 607 611	CeO2
# T14	KEYPHRASE 618 632	Acros Organics
# T15	KEYPHRASE 676 690	PuO2 surrogate
# T16	KEYPHRASE 692 721	Commercially available ground
# T17	KEYPHRASE 734 763	blast-furnace slag “Calumite”
# T18	KEYPHRASE 798 827	analysed chemical composition
# T19	KEYPHRASE 863 880	powdered material
# T20	KEYPHRASE 897 923	particle size distribution
#
#   +++ KLEIS +++
#
# T10	KEYPHRASE 863 880	powdered material
# T26	KEYPHRASE 418 423	steel
# T27	KEYPHRASE 425 434	aluminium
# T34	KEYPHRASE 580 588	concrete
# T46	KEYPHRASE 897 905	particle
# T50	KEYPHRASE 798 827	analysed chemical composition
# T74	KEYPHRASE 607 611	CeO2
# T82	KEYPHRASE 849 857	Calumite
# T84	KEYPHRASE 104 114	geometries
# T89	KEYPHRASE 240 244	lids
# T93	KEYPHRASE 183 192	PCM drums
# T94	KEYPHRASE 270 278	PVC bags
# T95	KEYPHRASE 542 561	waste Pyrex labware
# T151	KEYPHRASE 214 235	mild steel paint cans
# T190	KEYPHRASE 301 323	identical PVC sheeting
#
#   +++ RAW +++
#
# T1	Material 9 28	bounding PCM wastes
# T2	Material 116 135	“Mock up” PCM drums
# T3	Material 183 192	PCM drums
# T4	Material 214 244	mild steel paint cans and lids
# T5	Material 270 278	PVC bags
# T6	Material 301 323	identical PVC sheeting
# T7	Material 351 365	metallic waste
# T8	Material 386 423	commercial grade 18/8 stainless steel
# T9	Material 425 434	aluminium
# T10	Material 439 445	copper
# T11	Material 481 490	lead shot
# T12	Material 506 521	inorganic waste
# T13	Material 542 561	waste Pyrex labware
# T14	Material 571 578	masonry
# T15	Material 580 588	concrete
# T16	Material 593 605	window glass
# T17	Material 607 611	CeO2
# T18	Material 676 690	PuO2 surrogate
# T19	Material 734 763	blast-furnace slag “Calumite”
# T20	Material 849 857	Calumite
# T21	Material 863 880	powdered material
# R1	Hyponym-of Arg1:T20 Arg2:T21
# T22	Material 897 905	particle
#
#
# 2 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 77 114	describe the problem of cell tracking
# T2	KEYPHRASE 195 213	mathematical model
# T3	KEYPHRASE 230 240	image data
# T4	KEYPHRASE 262 291	geometric evolution law model
# T5	KEYPHRASE 319 362	simplification of recently developed models
# T6	KEYPHRASE 497 518	phase field framework
# T7	KEYPHRASE 580 615	formulate the cell tracking problem
# T8	KEYPHRASE 621 649	PDE constrained optimisation
# T9	KEYPHRASE 686 750	algorithm for the resolution of the PDE constrained optimisation
# T10	KEYPHRASE 926 947	multi-cell image data
# T11	KEYPHRASE 957 971	raw image data
# T12	KEYPHRASE 1052 1070	numerical examples
# T13	KEYPHRASE 1101 1122	multi-cell image data
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 195 213	mathematical model
# T11	KEYPHRASE 101 114	cell tracking
# T20	KEYPHRASE 21 31	discussion
# T26	KEYPHRASE 150 158	tracking
# T41	KEYPHRASE 556 563	problem
# T48	KEYPHRASE 686 695	algorithm
# T52	KEYPHRASE 812 826	implementation
# T57	KEYPHRASE 1009 1021	segmentation
# T63	KEYPHRASE 1245 1249	work
# T67	KEYPHRASE 621 624	PDE
# T68	KEYPHRASE 722 725	PDE
# T115	KEYPHRASE 779 796	practical aspects
# T116	KEYPHRASE 1052 1070	numerical examples
# T180	KEYPHRASE 145 158	cell tracking
# T189	KEYPHRASE 594 615	cell tracking problem
#
#   +++ RAW +++
#
# T1	Task 90 114	problem of cell tracking
# T3	Process 195 213	mathematical model
# T4	Material 217 245	experimental image data sets
# T5	Process 262 291	geometric evolution law model
# T6	Task 594 615	cell tracking problem
# T7	Task 621 657	PDE constrained optimisation problem
# T8	Process 686 695	algorithm
# T9	Task 722 758	PDE constrained optimisation problem
# T2	Process 859 898	theoretical and computational framework
# T10	Material 926 952	multi-cell image data sets
# T11	Material 957 976	raw image data sets
# T12	Material 1112 1127	image data sets
# T13	Task 119 158	introduce our approach to cell tracking
# T14	Process 497 518	phase field framework
# R1	Hyponym-of Arg1:T6 Arg2:T7
# T15	Process 478 487	our model
# T16	Process 1009 1021	segmentation
#
#
# 3 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 16	Zirconium alloys
# T2	KEYPHRASE 29 42	fuel cladding
# T3	KEYPHRASE 46 92	pressurised and boiling water nuclear reactors
# T4	KEYPHRASE 183 213	promote degradation mechanisms
# T5	KEYPHRASE 222 231	oxidation
# T6	KEYPHRASE 279 288	oxidation
# T7	KEYPHRASE 297 324	associated hydrogen pick-up
# T8	KEYPHRASE 362 377	fuel efficiency
# T9	KEYPHRASE 394 412	oxidation kinetics
# T10	KEYPHRASE 422 438	zirconium alloys
# T11	KEYPHRASE 493 513	cubic kinetic curves
# T12	KEYPHRASE 627 632	oxide
# T13	KEYPHRASE 735 744	oxidation
# T14	KEYPHRASE 757 825	developing a full mechanistic understanding of the corrosion process
#
#   +++ KLEIS +++
#
# T8	KEYPHRASE 29 42	fuel cladding
# T11	KEYPHRASE 362 377	fuel efficiency
# T13	KEYPHRASE 808 825	corrosion process
# T20	KEYPHRASE 222 231	oxidation
# T23	KEYPHRASE 279 288	oxidation
# T29	KEYPHRASE 382 388	safety
# T30	KEYPHRASE 394 403	oxidation
# T34	KEYPHRASE 582 591	breakdown
# T36	KEYPHRASE 627 632	oxide
# T39	KEYPHRASE 735 744	oxidation
# T56	KEYPHRASE 527 538	transitions
# T57	KEYPHRASE 552 563	transitions
# T63	KEYPHRASE 0 16	Zirconium alloys
# T154	KEYPHRASE 718 744	issues influence oxidation
#
#   +++ RAW +++
#
# T1	Material 76 92	nuclear reactors
# T2	Material 0 16	Zirconium alloys
# T3	Process 191 213	degradation mechanisms
# T4	Process 222 231	oxidation
# R1	Hyponym-of Arg1:T4 Arg2:T3
# T5	Process 279 288	oxidation
# T6	Process 308 324	hydrogen pick-up
# T7	Material 362 366	fuel
# T8	Process 394 403	oxidation
# T9	Material 422 438	zirconium alloys
# T10	Material 627 632	oxide
# T11	Task 694 744	Understanding how these issues influence oxidation
# T12	Task 757 825	developing a full mechanistic understanding of the corrosion process
# T13	Process 808 825	corrosion process
# T14	Process 735 744	oxidation
#
#
# 4 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 46 108	combination of Statistical Mechanics and nonlinear PDEs theory
# T2	KEYPHRASE 155 179	tackle phase transitions
# T3	KEYPHRASE 275 291	phase transition
# T4	KEYPHRASE 335 354	van der Waals model
# T5	KEYPHRASE 397 433	global mean field partition function
# T6	KEYPHRASE 451 487	system of finite number of particles
# T7	KEYPHRASE 533 554	Klein–Gordon equation
# T8	KEYPHRASE 556 584	reproduces the van der Waals
# T9	KEYPHRASE 637 711	thermodynamic limit N→∞ automatically encodes the Maxwell equal areas rule
# T10	KEYPHRASE 829 862	macroscopic thermodynamic systems
# T11	KEYPHRASE 922 967	class of models admitting partition functions
# T12	KEYPHRASE 998 1054	extend to the critical region general equations of state
#
#   +++ KLEIS +++
#
# T16	KEYPHRASE 493 511	partition function
# T23	KEYPHRASE 128 133	novel
# T43	KEYPHRASE 517 525	solution
# T56	KEYPHRASE 975 979	form
# T59	KEYPHRASE 1062 1066	form
# T68	KEYPHRASE 533 554	Klein–Gordon equation
# T78	KEYPHRASE 478 487	particles
# T83	KEYPHRASE 931 937	models
# T88	KEYPHRASE 263 291	first order phase transition
# T120	KEYPHRASE 61 82	Statistical Mechanics
# T136	KEYPHRASE 1083 1106	class virial expansions
# T196	KEYPHRASE 335 354	van der Waals model
# T214	KEYPHRASE 87 108	nonlinear PDEs theory
#
#   +++ RAW +++
#
# T1	Process 61 82	Statistical Mechanics
# T2	Process 87 108	nonlinear PDEs theory
# T3	Task 162 179	phase transitions
# T4	Process 263 291	first order phase transition
# T5	Process 335 354	van der Waals model
# T6	Process 409 433	field partition function
# T7	Process 493 511	partition function
# T8	Task 533 554	Klein–Gordon equation
# T9	Process 571 594	van der Waals isotherms
# T11	Process 687 711	Maxwell equal areas rule
# T10	Process 637 660	thermodynamic limit N→∞
# T12	Process 829 862	macroscopic thermodynamic systems
# T13	Process 1083 1106	class virial expansions
# T14	Process 1028 1066	general equations of state of the form
# T15	Process 948 979	partition functions of the form
# R1	Hyponym-of Arg1:T5 Arg2:T4
# T16	Process 805 809	spin
#
#
# 5 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 16 35	numerical framework
# T2	KEYPHRASE 40 55	two-phase flows
# T3	KEYPHRASE 64 106	implicit implementation of surface tension
# T4	KEYPHRASE 149 172	fully-coupled framework
# T5	KEYPHRASE 195 239	compare the influence of the surface tension
# T6	KEYPHRASE 257 310	time-step restrictions resulting from capillary waves
# T7	KEYPHRASE 370 420	numerical time-step resulting from capillary waves
# T8	KEYPHRASE 463 501	numerical treatment of surface tension
# T9	KEYPHRASE 509 524	surface tension
# T10	KEYPHRASE 606 663	affect the matrix coefficients of the primitive variables
# T11	KEYPHRASE 730 745	surface tension
# T12	KEYPHRASE 842 884	spatiotemporal sampling of capillary waves
# T13	KEYPHRASE 922 943	numerical methodology
#
#   +++ KLEIS +++
#
# T8	KEYPHRASE 675 694	numerical stability
# T13	KEYPHRASE 91 106	surface tension
# T16	KEYPHRASE 486 501	surface tension
# T17	KEYPHRASE 509 524	surface tension
# T18	KEYPHRASE 730 745	surface tension
# T26	KEYPHRASE 91 98	surface
# T38	KEYPHRASE 486 493	surface
# T40	KEYPHRASE 509 516	surface
# T43	KEYPHRASE 546 554	pressure
# T44	KEYPHRASE 558 566	velocity
# T46	KEYPHRASE 582 596	implementation
# T50	KEYPHRASE 730 737	surface
# T65	KEYPHRASE 350 362	restrictions
# T73	KEYPHRASE 40 55	two-phase flows
# T100	KEYPHRASE 295 310	capillary waves
# T101	KEYPHRASE 405 420	capillary waves
# T103	KEYPHRASE 869 884	capillary waves
# T157	KEYPHRASE 842 884	spatiotemporal sampling of capillary waves
# T180	KEYPHRASE 64 106	implicit implementation of surface tension
# T181	KEYPHRASE 463 501	numerical treatment of surface tension
#
#   +++ RAW +++
#
# T1	Process 2 35	fully-coupled numerical framework
# T2	Process 40 55	two-phase flows
# T3	Process 91 106	surface tension
# T4	Process 149 172	fully-coupled framework
# T5	Task 195 216	compare the influence
# T6	Process 224 249	surface tension treatment
# T7	Process 257 310	time-step restrictions resulting from capillary waves
# T8	Process 350 420	restrictions on the numerical time-step resulting from capillary waves
# T9	Process 463 501	numerical treatment of surface tension
# T10	Material 295 310	capillary waves
# T11	Material 405 420	capillary waves
# T12	Process 509 524	surface tension
# T13	Task 717 745	treatment of surface tension
# T14	Material 869 884	capillary waves
# T15	Task 842 884	spatiotemporal sampling of capillary waves
# T16	Process 914 943	applied numerical methodology
#
#
# 6 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 64 86	transportation systems
# T2	KEYPHRASE 93 104	simulations
# T3	KEYPHRASE 228 242	entire network
# T4	KEYPHRASE 256 282	global network performance
# T5	KEYPHRASE 376 402	global network performance
#
#   +++ KLEIS +++
#
# T29	KEYPHRASE 357 368	information
# T39	KEYPHRASE 571 582	Information
# T45	KEYPHRASE 791 798	traffic
# T48	KEYPHRASE 882 893	information
# T57	KEYPHRASE 93 104	simulations
# T59	KEYPHRASE 183 193	neighbours
# T63	KEYPHRASE 664 669	roads
# T70	KEYPHRASE 64 86	transportation systems
#
#   +++ RAW +++
#
# T1	Task 35 86	information dissemination in transportation systems
# T2	Process 93 104	simulations
# T3	Process 331 402	investigate the impact of information on the global network performance
# T4	Task 468 533	analyse what is the effect of real time information dissemination
# T5	Process 742 778	massive use of real-time information
# T6	Task 823 875	building more intelligent traffic control mechanisms
#
#
# 7 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 19	Magnox reactors
# T2	KEYPHRASE 40 73	generation of gas-cooled reactors
# T3	KEYPHRASE 81 83	UK
# T4	KEYPHRASE 94 108	carbon dioxide
# T5	KEYPHRASE 110 113	CO2
# T6	KEYPHRASE 144 180	honeycomb network of graphite bricks
# T7	KEYPHRASE 192 210	neutron moderation
# T8	KEYPHRASE 219 275	reactor operation significant amounts of carbon monoxide
# T9	KEYPHRASE 277 279	CO
# T10	KEYPHRASE 303 306	CO2
# T11	KEYPHRASE 321 323	CO
# T12	KEYPHRASE 376 413	carbonaceous deposit on free surfaces
# T13	KEYPHRASE 425 453	non-graphitic carbon deposit
# T14	KEYPHRASE 499 502	air
# T15	KEYPHRASE 569 584	Magnox reactors
# T16	KEYPHRASE 606 617	methane gas
# T17	KEYPHRASE 649 652	gas
# T18	KEYPHRASE 664 696	weight loss of the graphite core
# T19	KEYPHRASE 704 724	radiolytic oxidation
# T20	KEYPHRASE 740 743	CH4
# T21	KEYPHRASE 798 877	sacrificial layer protecting the underlying graphite from excessive weight loss
# T22	KEYPHRASE 940 987	nitrogen incorporation during deposit formation
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 704 724	radiolytic oxidation
# T13	KEYPHRASE 94 108	carbon dioxide
# T16	KEYPHRASE 260 275	carbon monoxide
# T18	KEYPHRASE 606 617	methane gas
# T22	KEYPHRASE 970 987	deposit formation
# T26	KEYPHRASE 94 100	carbon
# T32	KEYPHRASE 200 210	moderation
# T33	KEYPHRASE 219 226	reactor
# T35	KEYPHRASE 260 266	carbon
# T38	KEYPHRASE 327 331	turn
# T43	KEYPHRASE 499 502	air
# T44	KEYPHRASE 523 531	graphite
# T48	KEYPHRASE 614 617	gas
# T50	KEYPHRASE 649 652	gas
# T54	KEYPHRASE 715 724	oxidation
# T58	KEYPHRASE 842 850	graphite
# T62	KEYPHRASE 887 896	reduction
# T73	KEYPHRASE 303 314	CO2 coolant
# T75	KEYPHRASE 81 83	UK
# T76	KEYPHRASE 110 113	CO2
# T77	KEYPHRASE 277 279	CO
# T78	KEYPHRASE 303 306	CO2
# T79	KEYPHRASE 321 323	CO
# T81	KEYPHRASE 731 738	Methane
# T82	KEYPHRASE 740 743	CH4
# T92	KEYPHRASE 4 19	Magnox reactors
# T93	KEYPHRASE 569 584	Magnox reactors
# T120	KEYPHRASE 400 413	free surfaces
#
#   +++ RAW +++
#
# T1	Material 4 19	Magnox reactors
# T2	Material 54 73	gas-cooled reactors
# R1	Hyponym-of Arg1:T1 Arg2:T2
# T3	Material 94 108	carbon dioxide
# T4	Material 110 113	CO2
# *	Synonym-of T3 T4
# T5	Material 130 137	coolant
# R2	Hyponym-of Arg1:T4 Arg2:T5
# T6	Material 144 180	honeycomb network of graphite bricks
# T7	Process 192 210	neutron moderation
# T8	Material 192 199	neutron
# T9	Material 260 275	carbon monoxide
# T10	Material 277 279	CO
# *	Synonym-of T9 T10
# T11	Material 303 314	CO2 coolant
# T12	Material 321 323	CO
# T13	Process 339 365	radiolytically polymerised
# T14	Task 369 413	form a carbonaceous deposit on free surfaces
# T15	Material 425 453	non-graphitic carbon deposit
# T16	Material 499 502	air
# T17	Material 523 531	graphite
# T18	Material 569 584	Magnox reactors
# T19	Material 606 617	methane gas
# T20	Material 641 652	coolant gas
# T21	Material 683 696	graphite core
# T22	Process 704 724	radiolytic oxidation
# T23	Material 731 738	Methane
# T24	Material 740 743	CH4
# *	Synonym-of T23 T24
# T25	Material 842 850	graphite
# T26	Material 940 948	nitrogen
# T27	Task 656 724	inhibit weight loss of the graphite core due to radiolytic oxidation
# T28	Material 764 785	carbonaceous deposits
# T29	Process 887 919	reduction in mechanical strength
# T30	Process 940 987	nitrogen incorporation during deposit formation
# T31	Process 856 877	excessive weight loss
# T32	Material 219 226	reactor
#
#
# 8 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 26	Half metallic ferromagnets
# T2	KEYPHRASE 28 31	HMF
# T3	KEYPHRASE 95 113	spintronic devices
# T4	KEYPHRASE 119 149	Dilute magnetic semiconductors
# T5	KEYPHRASE 380 414	metal having un-paired d electrons
# T6	KEYPHRASE 462 492	utilization of electron's spin
# T7	KEYPHRASE 550 568	spintronic devices
# T8	KEYPHRASE 597 619	spin degree of freedom
# T9	KEYPHRASE 645 654	electrons
# T10	KEYPHRASE 798 856	research interest shifted towards large band gap materials
# T11	KEYPHRASE 913 918	II–VI
# T12	KEYPHRASE 923 943	III–V semiconductors
# T13	KEYPHRASE 1002 1006	TiO2
# T14	KEYPHRASE 1008 1012	SnO2
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 369 385	transition metal
# T19	KEYPHRASE 369 379	transition
# T24	KEYPHRASE 477 485	electron
# T25	KEYPHRASE 488 492	spin
# T30	KEYPHRASE 612 619	freedom
# T48	KEYPHRASE 28 31	HMF
# T50	KEYPHRASE 151 155	DMSs
# T52	KEYPHRASE 893 897	DMSs
# T53	KEYPHRASE 913 918	II–VI
# T55	KEYPHRASE 970 973	ZnS
# T56	KEYPHRASE 975 978	CdS
# T57	KEYPHRASE 980 983	GaN
# T58	KEYPHRASE 985 988	ZnO
# T59	KEYPHRASE 990 994	ZnSe
# T60	KEYPHRASE 996 1000	ZnTe
# T61	KEYPHRASE 1002 1006	TiO2
# T62	KEYPHRASE 1008 1012	SnO2
# T71	KEYPHRASE 405 414	electrons
# T72	KEYPHRASE 449 458	materials
# T75	KEYPHRASE 645 654	electrons
# T76	KEYPHRASE 713 722	materials
# T109	KEYPHRASE 0 26	Half metallic ferromagnets
# T110	KEYPHRASE 119 149	Dilute magnetic semiconductors
# T112	KEYPHRASE 95 113	spintronic devices
# T117	KEYPHRASE 550 568	spintronic devices
# T133	KEYPHRASE 272 295	semiconducting material
# T181	KEYPHRASE 522 568	advanced functionalities in spintronic devices
# T187	KEYPHRASE 913 943	II–VI and III–V semiconductors
#
#   +++ RAW +++
#
# T1	Material 0 26	Half metallic ferromagnets
# T2	Material 28 31	HMF
# T3	Task 95 113	spintronic devices
# T4	Material 119 149	Dilute magnetic semiconductors
# T5	Material 151 155	DMSs
# *	Synonym-of T4 T5
# *	Synonym-of T1 T2
# T6	Material 187 221	materials to show half metallicity
# R1	Hyponym-of Arg1:T5 Arg2:T6
# T7	Material 272 295	semiconducting material
# T8	Material 345 360	magnetic dopant
# T9	Material 369 385	transition metal
# R2	Hyponym-of Arg1:T9 Arg2:T8
# T10	Process 462 515	utilization of electron's spin as information carrier
# T11	Task 550 568	spintronic devices
# T12	Material 832 856	large band gap materials
# T13	Material 893 897	DMSs
# T14	Material 913 943	II–VI and III–V semiconductors
# T15	Material 970 973	ZnS
# T16	Material 975 978	CdS
# T17	Material 980 983	GaN
# T18	Material 985 988	ZnO
# T19	Material 990 994	ZnSe
# T20	Material 996 1000	ZnTe
# T21	Material 1002 1006	TiO2
# T22	Material 1008 1012	SnO2
# T23	Material 947 960	host material
# *	Synonym-of T14 T23
# R3	Hyponym-of Arg1:T15 Arg2:T23
# R4	Hyponym-of Arg1:T16 Arg2:T23
# R5	Hyponym-of Arg1:T17 Arg2:T23
# R6	Hyponym-of Arg1:T18 Arg2:T23
# R7	Hyponym-of Arg1:T19 Arg2:T23
# R8	Hyponym-of Arg1:T20 Arg2:T23
# R9	Hyponym-of Arg1:T21 Arg2:T23
# R10	Hyponym-of Arg1:T22 Arg2:T23
# T24	Task 729 781	enhance the Curie temperature above room temperature
# T25	Material 393 414	un-paired d electrons
# T26	Material 645 654	electrons
#
#
# 9 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 13 33	theoretical analysis
# T2	KEYPHRASE 52 70	measuring resistor
# T3	KEYPHRASE 97 114	corrosion process
# T4	KEYPHRASE 257 294	pair of nominally identical specimens
# T5	KEYPHRASE 385 402	calomel electrode
# T6	KEYPHRASE 427 466	NI-USB 6009 analog-to-digital converter
# T7	KEYPHRASE 472 493	electrochemical noise
# T8	KEYPHRASE 1053 1085	avoiding aliasing of frequencies
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 13 33	theoretical analysis
# T9	KEYPHRASE 97 114	corrosion process
# T25	KEYPHRASE 189 199	conclusion
# T31	KEYPHRASE 393 402	electrode
# T37	KEYPHRASE 601 610	iteration
# T65	KEYPHRASE 612 630	Between iterations
# T143	KEYPHRASE 265 294	nominally identical specimens
# T155	KEYPHRASE 520 547	in-house developed software
#
#   +++ RAW +++
#
# T1	Process 39 70	value of the measuring resistor
# T2	Process 72 74	Rm
# *	Synonym-of T2 T1
# T3	Material 427 466	NI-USB 6009 analog-to-digital converter
# T4	Material 322 336	4.7kΩ resistor
# T5	Material 375 402	saturated calomel electrode
# T6	Process 472 500	electrochemical noise signal
# T7	Material 520 547	in-house developed software
# T8	Material 778 785	dataset
# T10	Task 674 708	obtain a single value of potential
# T11	Task 979 1051	accurate recording of the potential noise in the frequencies of interest
# T12	Process 97 114	corrosion process
# T13	Process 136 161	value of noise resistance
# T14	Task 175 199	validate this conclusion
# T15	Material 257 294	pair of nominally identical specimens
# T16	Task 13 33	theoretical analysis
#
#
# 10 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 3 45	essential part of nuclear reactor analysis
# T2	KEYPHRASE 71 120	three-dimensional space-time kinetics of neutrons
# T3	KEYPHRASE 167 192	three-dimensional reactor
# T4	KEYPHRASE 250 265	reactor physics
# T5	KEYPHRASE 295 356	neutron diffusion theory applied to three-dimensional systems
# T6	KEYPHRASE 391 470	deterministic neutron transport solutions of two-dimensional lattice geometries
# T7	KEYPHRASE 548 576	reactor physics calculations
# T8	KEYPHRASE 603 623	Economic Cooperation
# T9	KEYPHRASE 642 663	Nuclear Energy Agency
# T10	KEYPHRASE 665 673	OECD-NEA
# T11	KEYPHRASE 692 740	ongoing benchmark entitled “Uncertainty Analysis
# T12	KEYPHRASE 744 754	Modelling”
# T13	KEYPHRASE 756 759	UAM
# T14	KEYPHRASE 836 867	computing lattice sensitivities
# T15	KEYPHRASE 878 929	DRAGON lattice code and WIMS-D4 multi-group library
# T16	KEYPHRASE 983 990	TSUNAMI
# T17	KEYPHRASE 1005 1036	Oak Ridge National Laboratories
#
#   +++ KLEIS +++
#
# T4	KEYPHRASE 295 312	neutron diffusion
# T21	KEYPHRASE 216 222	safety
# T30	KEYPHRASE 517 528	uncertainty
# T31	KEYPHRASE 533 544	sensitivity
# T41	KEYPHRASE 958 968	comparison
# T42	KEYPHRASE 21 45	nuclear reactor analysis
# T44	KEYPHRASE 295 319	neutron diffusion theory
# T55	KEYPHRASE 665 673	OECD-NEA
# T60	KEYPHRASE 756 759	UAM
# T62	KEYPHRASE 983 990	TSUNAMI
# T69	KEYPHRASE 112 120	neutrons
# T78	KEYPHRASE 778 785	efforts
# T158	KEYPHRASE 603 623	Economic Cooperation
#
#   +++ RAW +++
#
# T1	Task 21 45	nuclear reactor analysis
# T2	Task 53 120	prediction of the three-dimensional space-time kinetics of neutrons
# R1	Hyponym-of Arg1:T2 Arg2:T1
# T3	Material 185 197	reactor core
# T4	Material 112 120	neutrons
# T5	Material 21 36	nuclear reactor
# T6	Task 216 231	safety analyses
# T7	Task 236 275	prediction of reactor physics responses
# T8	Process 295 356	neutron diffusion theory applied to three-dimensional systems
# R2	Hyponym-of Arg1:T7 Arg2:T6
# T9	Process 391 432	deterministic neutron transport solutions
# T10	Material 405 412	neutron
# T11	Material 295 302	neutron
# T12	Task 548 576	reactor physics calculations
# T13	Material 548 555	reactor
# T14	Material 720 753	Uncertainty Analysis in Modelling
# T15	Material 756 759	UAM
# *	Synonym-of T14 T15
# T16	Task 823 867	strategy for computing lattice sensitivities
# T17	Material 902 929	WIMS-D4 multi-group library
# T18	Material 878 897	DRAGON lattice code
# T19	Process 983 990	TSUNAMI
# T20	Material 250 257	reactor
# T21	Process 436 470	two-dimensional lattice geometries
#
#
# 11 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 31 43	solar cell’s
# T2	KEYPHRASE 82 124	electrical characterisation of CPV modules
# T3	KEYPHRASE 220 255	High Concentrator PV (HCPV) modules
# T4	KEYPHRASE 300 309	heat sink
# T5	KEYPHRASE 357 379	atmospheric parameters
# T6	KEYPHRASE 419 438	direct measurements
# T7	KEYPHRASE 442 453	CPV modules
# T8	KEYPHRASE 541 563	Root Mean Square Error
# T9	KEYPHRASE 565 569	RMSE
# T10	KEYPHRASE 761 764	MPP
# T11	KEYPHRASE 789 807	realistic approach
# T12	KEYPHRASE 831 878	electrical energy generation of the solar cells
# T13	KEYPHRASE 987 1021	MPP based on electrical parameters
# T14	KEYPHRASE 1060 1122	heat sink temperature with absolute RMSE 0.55–1.44K. Fernández
# T15	KEYPHRASE 1155 1186	artificial neural network model
# T16	KEYPHRASE 1229 1251	atmospheric parameters
# T17	KEYPHRASE 1259 1316	open-circuit voltage model based on electrical parameters
# T18	KEYPHRASE 1367 1371	RMSE
# T19	KEYPHRASE 1453 1475	aforementioned methods
# T20	KEYPHRASE 1487 1505	experimental setup
#
#   +++ KLEIS +++
#
# T41	KEYPHRASE 457 463	indoor
# T81	KEYPHRASE 1259 1285	open-circuit voltage model
# T92	KEYPHRASE 242 246	HCPV
# T98	KEYPHRASE 565 569	RMSE
# T100	KEYPHRASE 761 764	MPP
# T102	KEYPHRASE 987 990	MPP
# T115	KEYPHRASE 261 268	methods
# T132	KEYPHRASE 113 124	CPV modules
# T133	KEYPHRASE 442 453	CPV modules
# T171	KEYPHRASE 82 124	electrical characterisation of CPV modules
# T179	KEYPHRASE 867 878	solar cells
# T182	KEYPHRASE 1295 1316	electrical parameters
# T183	KEYPHRASE 1453 1475	aforementioned methods
# T208	KEYPHRASE 220 240	High Concentrator PV
# T212	KEYPHRASE 1155 1186	artificial neural network model
#
#   +++ RAW +++
#
# T1	Material 31 41	solar cell
# T2	Process 113 116	CPV
# T3	Process 220 240	High Concentrator PV
# T4	Process 242 246	HCPV
# *	Synonym-of T3 T4
# T5	Process 442 445	CPV
# T6	Process 740 759	maximum power point
# T7	Process 761 764	MPP
# *	Synonym-of T6 T7
# T8	Process 670 693	open-circuit conditions
# T9	Material 650 654	cell
# T10	Material 200 204	cell
# T11	Material 867 878	solar cells
# T12	Process 831 859	electrical energy generation
# T13	Task 952 990	predicting the cell temperature at MPP
# T14	Process 987 990	MPP
# T15	Material 967 971	cell
# T16	Process 1155 1186	artificial neural network model
# T17	Task 1190 1219	estimate the cell temperature
# T18	Material 1203 1207	cell
# T19	Process 1259 1285	open-circuit voltage model
# T20	Task 1556 1584	cell temperature calculation
# T21	Material 1556 1560	cell
# T22	Task 181 216	calculation of the cell temperature
# T23	Task 17 55	prediction of solar cell’s temperature
# T24	Task 636 666	calculate the cell temperature
#
#
# 12 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 21	Structural properties
# T2	KEYPHRASE 130 147	elastic constants
# T3	KEYPHRASE 273 278	grain
# T4	KEYPHRASE 389 412	Morelon potential model
# T5	KEYPHRASE 462 497	replicate defect formation energies
# T6	KEYPHRASE 593 615	Arima potential models
# T7	KEYPHRASE 673 689	rigid ion models
# T8	KEYPHRASE 697 717	ionic polarisability
# T9	KEYPHRASE 777 789	shell models
# T10	KEYPHRASE 825 847	Catlow potential model
# T11	KEYPHRASE 874 902	Grimes shell potential model
# T12	KEYPHRASE 915 1048	reproduce the activation energy of oxygen migration (the migration path was the lowest energy and most favourable diffusion mechanism
# T13	KEYPHRASE 1066 1069	UO2
# T14	KEYPHRASE 1131 1144	cation defect
# T15	KEYPHRASE 1188 1202	cation defects
# T16	KEYPHRASE 1315 1349	grain growth where cation mobility
#
#   +++ KLEIS +++
#
# T8	KEYPHRASE 697 717	ionic polarisability
# T15	KEYPHRASE 950 966	oxygen migration
# T24	KEYPHRASE 207 216	structure
# T25	KEYPHRASE 221 231	elasticity
# T26	KEYPHRASE 273 278	grain
# T36	KEYPHRASE 736 743	account
# T37	KEYPHRASE 749 761	completeness
# T41	KEYPHRASE 929 939	activation
# T43	KEYPHRASE 950 956	oxygen
# T60	KEYPHRASE 1315 1320	grain
# T72	KEYPHRASE 1066 1069	UO2
# T75	KEYPHRASE 673 689	rigid ion models
# T99	KEYPHRASE 1188 1202	cation defects
# T122	KEYPHRASE 593 615	Arima potential models
# T125	KEYPHRASE 130 147	elastic constants
# T139	KEYPHRASE 1131 1153	cation defect energies
# T195	KEYPHRASE 389 412	Morelon potential model
# T196	KEYPHRASE 825 847	Catlow potential model
#
#   +++ RAW +++
#
# T1	Material 273 278	grain
# T2	Task 261 297	elucidating grain boundary stability
# T3	Task 330 383	predict the relative stability of the defect energies
# T4	Process 389 412	Morelon potential model
# T5	Task 462 497	replicate defect formation energies
# T6	Process 580 615	Morl and the Arima potential models
# T7	Process 673 689	rigid ion models
# R1	Hyponym-of Arg1:T6 Arg2:T7
# T8	Process 777 789	shell models
# T9	Process 825 847	Catlow potential model
# R2	Hyponym-of Arg1:T9 Arg2:T8
# T10	Process 853 902	Morl, along with the Grimes shell potential model
# T11	Material 950 956	oxygen
# T12	Task 915 966	reproduce the activation energy of oxygen migration
# T13	Material 1066 1069	UO2
# T14	Process 1104 1118	Morl potential
# T15	Material 1131 1137	cation
# T16	Material 1188 1194	cation
# T17	Process 1315 1327	grain growth
# T18	Process 972 986	migration path
# T19	Process 1029 1048	diffusion mechanism
# R3	Hyponym-of Arg1:T18 Arg2:T19
#
#
# 13 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 18 37	Kelvin wave problem
# T2	KEYPHRASE 229 257	astronomical tidal potential
# T3	KEYPHRASE 317 338	bottom boundary layer
# T4	KEYPHRASE 402 421	shallow-water waves
# T5	KEYPHRASE 442 454	Kelvin waves
# T6	KEYPHRASE 500 526	natural frequency ωf close
# T7	KEYPHRASE 542 561	forcing frequency ω
# T8	KEYPHRASE 772 791	numerical solutions
# T9	KEYPHRASE 811 823	forced waves
# T10	KEYPHRASE 878 900	spatial discretisation
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 371 386	forced response
# T11	KEYPHRASE 878 900	spatial discretisation
# T12	KEYPHRASE 942 957	forced response
# T21	KEYPHRASE 165 172	forcing
# T24	KEYPHRASE 215 222	surface
# T26	KEYPHRASE 267 274	damping
# T36	KEYPHRASE 643 647	ω≈ωf
# T53	KEYPHRASE 755 761	|ω−ωf|
# T61	KEYPHRASE 358 365	details
# T65	KEYPHRASE 487 492	waves
# T71	KEYPHRASE 442 454	Kelvin waves
# T77	KEYPHRASE 402 421	shallow-water waves
# T125	KEYPHRASE 811 823	forced waves
# T144	KEYPHRASE 13 37	free Kelvin wave problem
#
#   +++ RAW +++
#
# T1	Process 165 172	forcing
# T2	Process 191 222	wind stress at the free surface
# T3	Process 229 257	astronomical tidal potential
# T4	Process 267 274	damping
# T5	Process 295 338	turbulent stress of a bottom boundary layer
# T6	Process 371 386	forced response
# T7	Material 402 421	shallow-water waves
# T8	Material 442 454	Kelvin waves
# T9	Process 500 517	natural frequency
# T10	Process 518 520	ωf
# *	Synonym-of T10 T9
# T11	Process 542 559	forcing frequency
# T12	Process 560 561	ω
# *	Synonym-of T12 T11
# T13	Task 772 791	numerical solutions
# T14	Material 795 823	near-resonantly forced waves
# T16	Task 81 114	problems with forcing and damping
# T15	Task 13 37	free Kelvin wave problem
# T17	Material 191 195	wind
# T18	Material 487 492	waves
# T19	Process 643 644	ω
# T20	Process 645 647	ωf
# T21	Process 738 750	weak damping
# T22	Process 755 761	|ω−ωf|
# T23	Process 854 856	ωf
# T24	Process 878 900	spatial discretisation
# R1	Hyponym-of Arg1:T8 Arg2:T7
# R2	Hyponym-of Arg1:T7 Arg2:T18
# R3	Hyponym-of Arg1:T8 Arg2:T18
# T25	Material 18 29	Kelvin wave
#
#
# 14 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 168 240	measureable quantity characterising electrochemical behaviour of a metal
# T2	KEYPHRASE 254 292	scanning Kelvin probe force microscopy
# T3	KEYPHRASE 294 299	SKPFM
# T4	KEYPHRASE 318 340	detection of local EWF
# T5	KEYPHRASE 349 363	EWF of the tip
# T6	KEYPHRASE 378 405	Volta potential differences
# T7	KEYPHRASE 422 449	atomic force microscopy tip
# T8	KEYPHRASE 478 491	metal surface
# T9	KEYPHRASE 508 535	lateral resolution of SKPFM
# T10	KEYPHRASE 568 579	ambient air
# T11	KEYPHRASE 671 684	metal surface
# T12	KEYPHRASE 704 740	understand electrochemical processes
# T13	KEYPHRASE 779 794	surface defects
# T14	KEYPHRASE 796 815	chemical variations
# T15	KEYPHRASE 846 873	Volta potential differences
# T16	KEYPHRASE 910 937	predict corrosion behaviour
# T17	KEYPHRASE 977 1018	ΔΨ) indicate increased surface reactivity
# T18	KEYPHRASE 1062 1154	Volta potential differences measured in nominally dry air and their free corrosion potential
#
#   +++ KLEIS +++
#
# T17	KEYPHRASE 478 491	metal surface
# T18	KEYPHRASE 671 684	metal surface
# T24	KEYPHRASE 70 78	position
# T25	KEYPHRASE 108 115	surface
# T26	KEYPHRASE 122 130	position
# T27	KEYPHRASE 148 155	surface
# T35	KEYPHRASE 282 292	microscopy
# T38	KEYPHRASE 360 363	tip
# T39	KEYPHRASE 407 409	ΔΨ
# T48	KEYPHRASE 562 564	nm
# T49	KEYPHRASE 576 579	air
# T66	KEYPHRASE 977 979	ΔΨ
# T71	KEYPHRASE 1042 1053	correlation
# T72	KEYPHRASE 1116 1119	air
# T84	KEYPHRASE 29 30	Ψ
# T86	KEYPHRASE 294 299	SKPFM
# T91	KEYPHRASE 530 535	SKPFM
# T105	KEYPHRASE 422 449	atomic force microscopy tip
# T108	KEYPHRASE 779 794	surface defects
# T109	KEYPHRASE 796 815	chemical variations
# T132	KEYPHRASE 378 405	Volta potential differences
# T136	KEYPHRASE 715 740	electrochemical processes
# T173	KEYPHRASE 263 292	Kelvin probe force microscopy
# T246	KEYPHRASE 704 740	understand electrochemical processes
#
#   +++ RAW +++
#
# T1	Task 910 937	predict corrosion behaviour
# T2	Process 846 891	Volta potential differences in microstructure
# T3	Process 12 27	Volta potential
# T4	Process 29 30	Ψ
# *	Synonym-of T4 T3
# T5	Process 39 59	potential difference
# T6	Process 12 27	Volta potential
# R1	Hyponym-of Arg1:T5 Arg2:T6
# T7	Process 204 240	electrochemical behaviour of a metal
# T8	Process 254 292	scanning Kelvin probe force microscopy
# T9	Process 294 299	SKPFM
# *	Synonym-of T9 T8
# T10	Task 318 340	detection of local EWF
# T11	Task 378 405	Volta potential differences
# T12	Task 407 409	ΔΨ
# *	Synonym-of T12 T11
# T13	Material 422 449	atomic force microscopy tip
# T14	Material 459 468	Pt coated
# T15	Material 478 491	metal surface
# T16	Process 530 535	SKPFM
# T17	Process 621 636	Volta potential
# T18	Process 657 684	property of a metal surface
# R2	Hyponym-of Arg1:T18 Arg2:T17
# T19	Process 168 188	measureable quantity
# T20	Process 12 27	Volta potential
# R3	Hyponym-of Arg1:T19 Arg2:T20
# T21	Task 704 740	understand electrochemical processes
# T22	Process 969 1018	larger (ΔΨ) indicate increased surface reactivity
# T24	Process 1062 1089	Volta potential differences
# T25	Material 1112 1119	dry air
# T26	Process 1130 1154	free corrosion potential
# T27	Process 1156 1161	Ecorr
# *	Synonym-of T27 T26
# T28	Material 235 240	metal
# T29	Material 568 579	ambient air
# T30	Material 671 684	metal surface
# T31	Process 715 740	electrochemical processes
#
#
# 15 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 61 100	particle shape on interacting particles
# T2	KEYPHRASE 114 147	horizontal turbulent channel flow
# T3	KEYPHRASE 220 236	eddy simulations
# T4	KEYPHRASE 238 241	LES
# T5	KEYPHRASE 248 323	horizontal turbulent channel flow laden with five different particle shapes
# T6	KEYPHRASE 424 463	well-documented horizontal channel flow
# T7	KEYPHRASE 522 541	spherical particles
# T8	KEYPHRASE 617 641	phase Doppler anemometry
# T9	KEYPHRASE 643 646	PDA
# T10	KEYPHRASE 664 669	fluid
# T11	KEYPHRASE 712 731	numerical framework
# T12	KEYPHRASE 788 807	spherical particles
# T13	KEYPHRASE 826 836	van Wachem
# T14	KEYPHRASE 881 917	comprehensive discrete element model
# T15	KEYPHRASE 919 922	DEM
# T16	KEYPHRASE 944 986	determining the behaviour of the particles
# T17	KEYPHRASE 995 1028	horizontal gas–solid channel flow
# T18	KEYPHRASE 1094 1109	fluid mechanics
# T19	KEYPHRASE 1144 1157	LES framework
# T20	KEYPHRASE 1223 1246	non-spherical particles
#
#   +++ KLEIS +++
#
# T5	KEYPHRASE 712 731	numerical framework
# T8	KEYPHRASE 1038 1055	hard-sphere model
# T24	KEYPHRASE 61 69	particle
# T32	KEYPHRASE 308 316	particle
# T33	KEYPHRASE 343 347	drag
# T34	KEYPHRASE 349 353	lift
# T46	KEYPHRASE 664 669	fluid
# T47	KEYPHRASE 674 682	particle
# T59	KEYPHRASE 1094 1099	fluid
# T62	KEYPHRASE 1186 1195	framework
# T72	KEYPHRASE 1144 1157	LES framework
# T74	KEYPHRASE 238 241	LES
# T79	KEYPHRASE 643 646	PDA
# T82	KEYPHRASE 919 922	DEM
# T91	KEYPHRASE 153 162	particles
# T92	KEYPHRASE 225 236	simulations
# T97	KEYPHRASE 977 986	particles
# T108	KEYPHRASE 308 323	particle shapes
# T109	KEYPHRASE 1094 1109	fluid mechanics
# T138	KEYPHRASE 522 541	spherical particles
# T139	KEYPHRASE 788 807	spherical particles
# T140	KEYPHRASE 1223 1246	non-spherical particles
# T161	KEYPHRASE 79 100	interacting particles
# T165	KEYPHRASE 214 236	large eddy simulations
# T166	KEYPHRASE 114 147	horizontal turbulent channel flow
#
#   +++ RAW +++
#
# T1	Task 28 147	investigate the influence of the particle shape on interacting particles flowing in a horizontal turbulent channel flow
# T2	Process 214 236	large eddy simulations
# T3	Process 238 241	LES
# R1	Hyponym-of Arg1:T2 Arg2:T3
# T4	Material 308 316	particle
# T5	Process 343 369	drag, lift and toque model
# T6	Process 248 281	horizontal turbulent channel flow
# T7	Process 440 463	horizontal channel flow
# T8	Material 522 541	spherical particles
# T9	Process 617 641	phase Doppler anemometry
# T10	Process 643 646	PDA
# *	Synonym-of T9 T10
# T11	Material 664 669	fluid
# T12	Material 674 682	particle
# T13	Process 712 731	numerical framework
# T14	Material 788 807	spherical particles
# T15	Process 881 917	comprehensive discrete element model
# T16	Process 919 922	DEM
# *	Synonym-of T15 T16
# T17	Process 1038 1055	hard-sphere model
# T18	Task 944 1028	determining the behaviour of the particles in this horizontal gas–solid channel flow
# T19	Material 1094 1099	fluid
# T20	Process 1144 1157	LES framework
# T21	Material 1223 1246	non-spherical particles
# T22	Material 153 162	particles
# T23	Material 977 986	particles
# T24	Process 1006 1028	gas–solid channel flow
# T25	Material 1006 1009	gas
# T26	Material 91 100	particles
#
#
# 16 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 61 95	hard sphere and soft sphere models
# T2	KEYPHRASE 157 184	particle equation of motion
# T3	KEYPHRASE 195 207	dilute flows
# T4	KEYPHRASE 346 363	soft sphere model
# T5	KEYPHRASE 376 392	realistic option
# T6	KEYPHRASE 446 461	collision model
# T7	KEYPHRASE 556 573	experimental data
# T8	KEYPHRASE 623 628	walls
# T9	KEYPHRASE 658 685	hard and soft sphere models
# T10	KEYPHRASE 701 706	walls
# T11	KEYPHRASE 767 794	hard and soft sphere models
# T12	KEYPHRASE 809 814	walls
# T13	KEYPHRASE 852 925	wall treatment in the soft sphere implementation adds extra virtual walls
# T14	KEYPHRASE 990 1014	realistic representation
# T15	KEYPHRASE 1065 1101	wall treatment where one random wall
# T16	KEYPHRASE 1268 1284	fluid statistics
# T17	KEYPHRASE 1323 1353	particle velocity fluctuations
# T18	KEYPHRASE 1441 1480	particle mean and RMS velocity profiles
#
#   +++ KLEIS +++
#
# T9	KEYPHRASE 556 573	experimental data
# T22	KEYPHRASE 446 461	collision model
# T34	KEYPHRASE 157 165	particle
# T36	KEYPHRASE 178 184	motion
# T46	KEYPHRASE 584 594	comparison
# T53	KEYPHRASE 952 960	particle
# T54	KEYPHRASE 968 972	wall
# T61	KEYPHRASE 1097 1101	wall
# T65	KEYPHRASE 1268 1273	fluid
# T66	KEYPHRASE 1323 1331	particle
# T68	KEYPHRASE 1441 1449	particle
# T72	KEYPHRASE 1589 1600	restitution
# T78	KEYPHRASE 1459 1462	RMS
# T79	KEYPHRASE 1602 1603	ψ
# T91	KEYPHRASE 277 287	collisions
# T93	KEYPHRASE 540 546	models
# T102	KEYPHRASE 1240 1247	effects
# T105	KEYPHRASE 1370 1381	differences
# T115	KEYPHRASE 1268 1284	fluid statistics
# T185	KEYPHRASE 1323 1353	particle velocity fluctuations
# T204	KEYPHRASE 1497 1519	hard sphere collisions
#
#   +++ RAW +++
#
# T1	Material 25 37	dilute flows
# T2	Process 61 95	hard sphere and soft sphere models
# T3	Task 147 184	solve the particle equation of motion
# T4	Process 213 230	hard sphere model
# T5	Material 195 207	dilute flows
# T6	Process 346 363	soft sphere model
# T7	Process 446 461	collision model
# T8	Process 658 685	hard and soft sphere models
# T9	Process 767 794	hard and soft sphere models
# T10	Material 616 628	smooth walls
# T11	Material 694 706	smooth walls
# T12	Material 803 814	rough walls
# T13	Task 846 866	rough wall treatment
# T14	Process 874 900	soft sphere implementation
# T15	Material 952 960	particle
# T16	Material 912 925	virtual walls
# T17	Material 968 972	wall
# T18	Material 1020 1030	rough wall
# T19	Task 1047 1079	hard sphere rough wall treatment
# T20	Material 1090 1101	random wall
# R1	Hyponym-of Arg1:T19 Arg2:T13
# T21	Material 1268 1273	fluid
# T22	Material 1323 1331	particle
# T23	Material 1441 1449	particle
# T24	Process 1136 1157	soft sphere collision
# R2	Hyponym-of Arg1:T18 Arg2:T17
# R3	Hyponym-of Arg1:T20 Arg2:T17
# R4	Hyponym-of Arg1:T16 Arg2:T17
# T25	Process 1497 1519	hard sphere collisions
#
#
# 17 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 78 89	fine oxides
# T2	KEYPHRASE 99 109	ODS steels
# T3	KEYPHRASE 185 210	complete characterisation
# T4	KEYPHRASE 218 233	oxide particles
# T5	KEYPHRASE 314 331	chemical variants
# T6	KEYPHRASE 502 506	Y2O3
# T7	KEYPHRASE 511 525	Y2Ti2O7 oxides
# T8	KEYPHRASE 706 718	oxide phases
# T9	KEYPHRASE 742 754	Ti additions
# T10	KEYPHRASE 767 776	ODS alloy
# T11	KEYPHRASE 854 870	equivalent alloy
# T12	KEYPHRASE 879 887	titanium
# T13	KEYPHRASE 1002 1032	phase particles and the matrix
# T14	KEYPHRASE 1101 1103	Ti
# T15	KEYPHRASE 1105 1113	O system
# T16	KEYPHRASE 1147 1160	low interface
# T17	KEYPHRASE 1384 1414	oxide structure and variations
# T18	KEYPHRASE 1485 1511	irradiation induced damage
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 37 54	crystal structure
# T3	KEYPHRASE 245 262	crystal structure
# T10	KEYPHRASE 1384 1399	oxide structure
# T17	KEYPHRASE 20 26	debate
# T22	KEYPHRASE 218 223	oxide
# T24	KEYPHRASE 267 278	composition
# T26	KEYPHRASE 418 429	irradiation
# T28	KEYPHRASE 579 587	particle
# T37	KEYPHRASE 879 887	titanium
# T41	KEYPHRASE 1026 1032	matrix
# T49	KEYPHRASE 1253 1263	pyrochlore
# T53	KEYPHRASE 1352 1363	irradiation
# T55	KEYPHRASE 1418 1429	composition
# T57	KEYPHRASE 1485 1496	irradiation
# T63	KEYPHRASE 1105 1113	O system
# T68	KEYPHRASE 502 506	Y2O3
# T75	KEYPHRASE 1098 1099	Y
# T76	KEYPHRASE 1101 1103	Ti
# T80	KEYPHRASE 83 89	oxides
# T94	KEYPHRASE 822 833	dispersoids
# T99	KEYPHRASE 1344 1348	ways
# T100	KEYPHRASE 1404 1414	variations
# T101	KEYPHRASE 99 109	ODS steels
# T110	KEYPHRASE 218 233	oxide particles
# T172	KEYPHRASE 245 278	crystal structure and composition
#
#   +++ RAW +++
#
# T1	Material 78 89	fine oxides
# T2	Material 99 109	ODS steels
# T3	Material 37 44	crystal
# T4	Material 218 233	oxide particles
# T5	Material 245 252	crystal
# T6	Task 185 233	complete characterisation of the oxide particles
# T7	Material 502 506	Y2O3
# T8	Material 511 525	Y2Ti2O7 oxides
# T9	Material 579 587	particle
# T10	Material 706 711	oxide
# T11	Material 742 744	Ti
# T12	Material 616 618	Ti
# T13	Material 761 776	18%Cr ODS alloy
# T14	Process 802 818	coarsening rates
# T15	Material 822 833	dispersoids
# T16	Material 865 870	alloy
# T17	Material 879 887	titanium
# T18	Process 923 939	coarsening rates
# T19	Material 1008 1017	particles
# T20	Material 1026 1032	matrix
# T21	Material 1098 1099	Y
# T22	Material 1101 1103	Ti
# T23	Material 1105 1106	O
# T24	Material 1253 1263	pyrochlore
# T25	Material 1302 1312	pyrochlore
# T26	Process 1352 1363	irradiation
# T27	Material 1384 1389	oxide
# T28	Process 1485 1496	irradiation
# T29	Process 418 429	irradiation
#
#
# 18 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 31	data acquisition strategies
# T2	KEYPHRASE 124 144	statistical modeling
# T3	KEYPHRASE 258 293	develop a working network of models
# T4	KEYPHRASE 303 319	active mechanism
# T5	KEYPHRASE 363 432	mesoscopic physical level and the data-driven statistical model level
# T6	KEYPHRASE 449 512	temporal evolution of the energy material over long time frames
# T7	KEYPHRASE 514 545	appropriate informatics methods
# T8	KEYPHRASE 560 572	balance data
# T9	KEYPHRASE 594 629	univariate time-series data streams
# T10	KEYPHRASE 635 679	high-dimensional volumetric imaging datasets
# T11	KEYPHRASE 750 758	raw data
# T12	KEYPHRASE 843 862	modeling approaches
# T13	KEYPHRASE 871 916	understand and parameterize active mechanisms
# T14	KEYPHRASE 997 1019	macroscopic approaches
# T15	KEYPHRASE 1036 1062	real-world experimentation
# T16	KEYPHRASE 1096 1125	development of network models
# T17	KEYPHRASE 1130 1170	mesoscopic evolution of energy materials
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 124 144	statistical modeling
# T5	KEYPHRASE 303 319	active mechanism
# T11	KEYPHRASE 750 758	raw data
# T18	KEYPHRASE 475 490	energy material
# T23	KEYPHRASE 136 144	modeling
# T26	KEYPHRASE 236 247	information
# T29	KEYPHRASE 336 347	degradation
# T43	KEYPHRASE 808 813	query
# T44	KEYPHRASE 818 826	modeling
# T46	KEYPHRASE 921 930	phenomena
# T60	KEYPHRASE 514 545	appropriate informatics methods
# T83	KEYPHRASE 1064 1075	informatics
# T84	KEYPHRASE 1077 1086	analytics
# T93	KEYPHRASE 843 862	modeling approaches
# T172	KEYPHRASE 1096 1125	development of network models
#
#   +++ RAW +++
#
# T1	Process 4 31	data acquisition strategies
# T2	Task 111 144	physical and statistical modeling
# T3	Task 161 200	extraction of the necessary information
# T4	Process 409 426	statistical model
# T5	Task 437 467	capture the temporal evolution
# T6	Material 475 490	energy material
# T7	Material 594 629	univariate time-series data streams
# T8	Material 635 679	high-dimensional volumetric imaging datasets
# T9	Process 979 1019	micro-, meso- and macroscopic approaches
# T10	Task 1096 1125	development of network models
# T11	Material 1154 1170	energy materials
# T12	Task 1218 1237	degradation science
# T13	Task 808 813	query
# T14	Task 818 826	modeling
# T15	Process 514 545	appropriate informatics methods
# T16	Process 843 862	modeling approaches
# R1	Hyponym-of Arg1:T9 Arg2:T16
# T17	Process 276 293	network of models
# T18	Task 1064 1075	informatics
# T19	Task 1077 1086	analytics
# T20	Task 1021 1062	Laboratory and real-world experimentation
# R2	Hyponym-of Arg1:T20 Arg2:T12
# R3	Hyponym-of Arg1:T18 Arg2:T12
# R4	Hyponym-of Arg1:T19 Arg2:T12
# R5	Hyponym-of Arg1:T10 Arg2:T12
#
#
# 19 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 59 114	homonuclear chains of tangent Mie spherical CG segments
# T2	KEYPHRASE 120 144	development of CG models
# T3	KEYPHRASE 271 291	SAFT-γ Mie formalism
# T4	KEYPHRASE 360 432	n-eicosane chains of six fully flexible tangentially bonded Mie segments
# T5	KEYPHRASE 567 582	EOS description
# T6	KEYPHRASE 633 643	CG mapping
# T7	KEYPHRASE 742 763	carbon backbone atoms
# T8	KEYPHRASE 788 802	hydrogen atoms
# T9	KEYPHRASE 830 889	n-alkanes chains containing multiples of three carbon units
# T10	KEYPHRASE 1069 1083	CG alkyl beads
# T11	KEYPHRASE 1224 1232	CG beads
# T12	KEYPHRASE 1360 1366	carbon
# T13	KEYPHRASE 1390 1420	size σ and energy ∊ parameters
# T14	KEYPHRASE 1449 1573	experimental saturated-liquid density and vapour pressure of the individual alkanes following the usual SAFT-γ Mie procedure
# T15	KEYPHRASE 1579 1593	chosen mapping
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 303 320	n-decane molecule
# T19	KEYPHRASE 1579 1593	chosen mapping
# T40	KEYPHRASE 699 706	segment
# T41	KEYPHRASE 742 748	carbon
# T45	KEYPHRASE 821 828	mapping
# T49	KEYPHRASE 1131 1142	convenience
# T56	KEYPHRASE 1360 1366	carbon
# T71	KEYPHRASE 567 582	EOS description
# T80	KEYPHRASE 567 570	EOS
# T82	KEYPHRASE 1069 1071	CG
# T92	KEYPHRASE 25 34	n-alkanes
# T108	KEYPHRASE 1032 1039	alkanes
# T121	KEYPHRASE 135 144	CG models
# T132	KEYPHRASE 788 802	hydrogen atoms
# T205	KEYPHRASE 742 763	carbon backbone atoms
# T231	KEYPHRASE 271 291	SAFT-γ Mie formalism
# T318	KEYPHRASE 4 34	homologous series of n-alkanes
#
#   +++ RAW +++
#
# T1	Task 120 163	development of CG models for long n-alkanes
# T2	Process 271 291	SAFT-γ Mie formalism
# T3	Material 172 180	n-decane
# T4	Material 182 190	n-C10H22
# *	Synonym-of T4 T3
# T5	Material 196 206	n-eicosane
# T6	Material 208 216	n-C20H42
# *	Synonym-of T6 T5
# T7	Material 59 114	homonuclear chains of tangent Mie spherical CG segments
# T8	Material 4 34	homologous series of n-alkanes
# T9	Material 303 320	n-decane molecule
# T10	Material 360 370	n-eicosane
# T12	Process 621 643	alternative CG mapping
# T13	Material 648 657	n-alkanes
# T15	Material 919 926	n-C6H14
# T16	Material 928 935	n-C9H20
# T17	Material 937 945	n-C12H26
# T18	Material 947 955	n-C15H32
# T19	Material 957 965	n-C18H38
# T20	Task 979 1022	description of the thermodynamic properties
# T21	Material 1069 1083	CG alkyl beads
# T22	Process 1105 1125	Mie (15–6) potential
# T23	Process 1553 1573	SAFT-γ Mie procedure
# T28	Process 1462 1486	saturated-liquid density
# T29	Process 1491 1506	vapour pressure
# T11	Material 420 432	Mie segments
# T14	Material 736 763	alkyl carbon backbone atoms
# T30	Material 788 802	hydrogen atoms
# T31	Material 830 846	n-alkanes chains
# T32	Material 877 889	carbon units
# R1	Hyponym-of Arg1:T15 Arg2:T31
# R2	Hyponym-of Arg1:T16 Arg2:T31
# R3	Hyponym-of Arg1:T17 Arg2:T31
# R4	Hyponym-of Arg1:T18 Arg2:T31
# R5	Hyponym-of Arg1:T19 Arg2:T31
# T33	Material 1032 1039	alkanes
# T34	Material 1224 1232	CG beads
# T35	Material 1252 1259	alkanes
# T36	Material 1360 1366	carbon
# T24	Material 1525 1532	alkanes
#
#
# 20 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 30 73	accurate measurement of DNI started decades
# T2	KEYPHRASE 196 199	DNI
# T3	KEYPHRASE 557 595	WMO Task Group meeting held in Belgium
# T4	KEYPHRASE 605 608	WMO
# T5	KEYPHRASE 619 670	improve the accuracy of pyrheliometric measurements
# T6	KEYPHRASE 870 892	instrument geometry vs
# T7	KEYPHRASE 1070 1073	WMO
# T8	KEYPHRASE 1102 1140	recommended geometry of pyrheliometers
# T9	KEYPHRASE 1169 1187	standard” geometry
# T10	KEYPHRASE 1274 1277	DNI
#
#   +++ KLEIS +++
#
# T17	KEYPHRASE 94 98	e.g.
# T23	KEYPHRASE 269 272	sun
# T30	KEYPHRASE 501 507	latter
# T34	KEYPHRASE 800 805	topic
# T46	KEYPHRASE 54 57	DNI
# T50	KEYPHRASE 196 199	DNI
# T52	KEYPHRASE 557 560	WMO
# T56	KEYPHRASE 605 608	WMO
# T59	KEYPHRASE 1070 1073	WMO
# T61	KEYPHRASE 1274 1277	DNI
# T65	KEYPHRASE 385 399	pyrheliometers
# T75	KEYPHRASE 1126 1140	pyrheliometers
# T78	KEYPHRASE 1169 1187	standard” geometry
# T106	KEYPHRASE 79 92	Early studies
# T109	KEYPHRASE 643 670	pyrheliometric measurements
#
#   +++ RAW +++
#
# T1	Task 166 272	separating the measurement of DNI from that of the diffuse irradiance in the immediate vicinity of the sun
# T2	Task 360 459	study of the geometry of pyrheliometers, and how that geometry interacted with circumsolar radiance
# T3	Task 619 722	improve the accuracy of pyrheliometric measurements, including estimates of the circumsolar enhancement
# T4	Material 1126 1140	pyrheliometers
# T5	Material 385 399	pyrheliometers
#
#
# 21 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 30	Complex Langevin (CL) dynamics
# T2	KEYPHRASE 77 89	sign problem
# T3	KEYPHRASE 93 140	numerical simulations of lattice field theories
# T4	KEYPHRASE 305 331	nonzero chemical potential
# T5	KEYPHRASE 351 382	four-dimensional field theories
# T6	KEYPHRASE 397 409	sign problem
# T7	KEYPHRASE 787 860	positive probability distribution in the complexified configuration space
# T8	KEYPHRASE 902 918	Langevin process
# T9	KEYPHRASE 1046 1048	CL
# T10	KEYPHRASE 1145 1170	nonabelian gauge theories
# T11	KEYPHRASE 1181 1220	implementation of SL(N,C) gauge cooling
#
#   +++ KLEIS +++
#
# T14	KEYPHRASE 77 89	sign problem
# T15	KEYPHRASE 200 219	importance sampling
# T34	KEYPHRASE 545 554	inception
# T47	KEYPHRASE 962 972	conclusion
# T48	KEYPHRASE 987 999	distribution
# T59	KEYPHRASE 902 918	Langevin process
# T61	KEYPHRASE 18 20	CL
# T67	KEYPHRASE 1046 1048	CL
# T68	KEYPHRASE 1199 1201	SL
# T70	KEYPHRASE 1204 1205	C
# T73	KEYPHRASE 1145 1170	nonabelian gauge theories
#
#   +++ RAW +++
#
# T1	Process 0 16	Complex Langevin
# T2	Process 18 20	CL
# *	Synonym-of T2 T1
# T5	Process 305 331	nonzero chemical potential
# T10	Process 828 860	complexified configuration space
# T11	Process 902 918	Langevin process
# T12	Process 1046 1048	CL
# ...
# T30	Material 409 417	actinide
# T31	Process 789 795	burnup
#
#
# 44 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 67 87	polyatomic molecules
# T2	KEYPHRASE 102 131	intense ultrafast laser field
# T3	KEYPHRASE 146 236	exhibit sensitive dependence on the instantaneous phase characteristics of the laser field
# T4	KEYPHRASE 265 294	sign the chirped laser pulses
# T5	KEYPHRASE 393 461	laser induced molecular fragmentation with chirped femtosecond laser
# T6	KEYPHRASE 516 535	theoretical effects
# T7	KEYPHRASE 688 704	molecular system
# T8	KEYPHRASE 785 826	fragmentation pathway of n-propyl benzene
# T9	KEYPHRASE 862 883	fragmentation channel
# T10	KEYPHRASE 913 929	n-propyl benzene
# T11	KEYPHRASE 1002 1013	laser pulse
# T12	KEYPHRASE 1291 1304	fragment ions
#
#   +++ KLEIS +++
#
# T8	KEYPHRASE 688 704	molecular system
# T11	KEYPHRASE 913 929	n-propyl benzene
# T17	KEYPHRASE 225 236	laser field
# T22	KEYPHRASE 1002 1013	laser pulse
# T27	KEYPHRASE 40 53	fragmentation
# T37	KEYPHRASE 296 309	fragmentation
# T49	KEYPHRASE 711 716	study
# T54	KEYPHRASE 819 826	benzene
# T57	KEYPHRASE 922 929	benzene
# T72	KEYPHRASE 1361 1369	molecule
# T74	KEYPHRASE 1406 1411	chirp
# T81	KEYPHRASE 953 958	C3H3+
# T82	KEYPHRASE 1140 1145	C3H3+
# T92	KEYPHRASE 566 573	efforts
# T139	KEYPHRASE 67 87	polyatomic molecules
# T230	KEYPHRASE 672 704	function of the molecular system
#
#   +++ RAW +++
#
# T1	Process 40 63	fragmentation processes
# T2	Material 67 87	polyatomic molecules
# T3	Material 102 131	intense ultrafast laser field
# T4	Material 225 236	laser field
# *	Synonym-of T3 T4
# T5	Material 274 294	chirped laser pulses
# T6	Process 393 430	laser induced molecular fragmentation
# T7	Material 436 468	chirped femtosecond laser pulses
# T8	Task 604 632	fragment channel enhancement
# T9	Task 748 806	observation of a coherently enhanced fragmentation pathway
# T10	Material 810 826	n-propyl benzene
# T11	Material 862 883	fragmentation channel
# T12	Material 913 929	n-propyl benzene
# T13	Material 953 958	C3H3+
# T14	Material 1002 1013	laser pulse
# T15	Process 688 704	molecular system
# T16	Material 1055 1063	channels
# T17	Material 1140 1145	C3H3+
# T18	Material 1151 1176	negatively chirped pulses
# T19	Material 1221 1235	positive chirp
# T20	Material 1283 1304	heavier fragment ions
# T21	Material 1361 1369	molecule
# T22	Material 1406 1411	chirp
# R1	Hyponym-of Arg1:T14 Arg2:T16
# R2	Hyponym-of Arg1:T20 Arg2:T21
# T23	Task 296 309	fragmentation
#
#
# 45 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 40	Statistical Associating Fluid Theory
# T2	KEYPHRASE 42 46	SAFT
# T3	KEYPHRASE 53 87	well-developed perturbation theory
# T4	KEYPHRASE 124 155	volumetric properties of fluids
# T5	KEYPHRASE 379 460	intermolecular potential employed to describe the unbounded constituent particles
# T6	KEYPHRASE 496 505	LJ fluids
# T7	KEYPHRASE 548 564	reference fluids
# T8	KEYPHRASE 598 602	SAFT
# T9	KEYPHRASE 679 687	SAFT EoS
# T10	KEYPHRASE 698 705	SAFT-VR
# T11	KEYPHRASE 772 799	group contribution approach
# T12	KEYPHRASE 864 868	SAFT
# T13	KEYPHRASE 1004 1040	generalized form of the LJ potential
# T14	KEYPHRASE 1138 1157	analytical function
# T15	KEYPHRASE 1499 1511	Mie function
# T16	KEYPHRASE 1620 1638	isotropic molecule
# T17	KEYPHRASE 1704 1726	fluid phase equilibria
# T18	KEYPHRASE 1909 1949	dispersion scaling of most simple fluids
#
#   +++ KLEIS +++
#
# T20	KEYPHRASE 1620 1638	isotropic molecule
# T25	KEYPHRASE 161 167	reader
# T26	KEYPHRASE 206 211	topic
# T31	KEYPHRASE 507 512	argon
# T47	KEYPHRASE 986 987	m
# T52	KEYPHRASE 1101 1105	form
# T54	KEYPHRASE 1110 1111	r
# T56	KEYPHRASE 1165 1174	repulsive
# T57	KEYPHRASE 1201 1203	λa
# T58	KEYPHRASE 1208 1210	λr
# T69	KEYPHRASE 1491 1493	kB
# T80	KEYPHRASE 1954 1959	refer
# T82	KEYPHRASE 2003 2007	λ=λr
# T84	KEYPHRASE 2041 2042	r
# T88	KEYPHRASE 1704 1726	fluid phase equilibria
# T92	KEYPHRASE 1325 1333	Mie bead
# T94	KEYPHRASE 1499 1511	Mie function
# T99	KEYPHRASE 42 46	SAFT
# T102	KEYPHRASE 598 602	SAFT
# T103	KEYPHRASE 679 683	SAFT
# T108	KEYPHRASE 801 807	SAFT-γ
# T110	KEYPHRASE 864 868	SAFT
# T116	KEYPHRASE 1226 1227	σ
# T121	KEYPHRASE 1669 1671	λr
# T122	KEYPHRASE 2053 2056	λ−6
# T126	KEYPHRASE 149 155	fluids
# T130	KEYPHRASE 349 357	versions
# T134	KEYPHRASE 514 521	alkanes
# T138	KEYPHRASE 1065 1072	decades
# T148	KEYPHRASE 496 505	LJ fluids
# T228	KEYPHRASE 4 33	Statistical Associating Fluid
# T294	KEYPHRASE 679 687	SAFT EoS
# T323	KEYPHRASE 4 40	Statistical Associating Fluid Theory
#
#   +++ RAW +++
#
# T1	Process 4 40	Statistical Associating Fluid Theory
# T2	Process 42 46	SAFT
# *	Synonym-of T1 T2
# T3	Process 68 87	perturbation theory
# R1	Hyponym-of Arg1:T2 Arg2:T3
# T4	Material 149 155	fluids
# T5	Process 379 403	intermolecular potential
# T6	Material 429 460	unbounded constituent particles
# T7	Material 462 474	Hard spheres
# T8	Material 476 494	square well fluids
# T9	Material 496 505	LJ fluids
# T10	Material 507 512	argon
# T11	Material 514 521	alkanes
# T12	Material 548 564	reference fluids
# T13	Process 598 602	SAFT
# R2	Hyponym-of Arg1:T6 Arg2:T12
# R3	Hyponym-of Arg1:T7 Arg2:T12
# R4	Hyponym-of Arg1:T8 Arg2:T12
# R5	Hyponym-of Arg1:T9 Arg2:T12
# R6	Hyponym-of Arg1:T10 Arg2:T12
# R7	Hyponym-of Arg1:T11 Arg2:T12
# T14	Process 679 687	SAFT EoS
# T15	Process 698 709	SAFT-VR Mie
# R8	Hyponym-of Arg1:T15 Arg2:T14
# T16	Process 772 799	group contribution approach
# T17	Process 801 807	SAFT-γ
# R9	Hyponym-of Arg1:T17 Arg2:T16
# R10	Hyponym-of Arg1:T17 Arg2:T15
# T18	Process 864 868	SAFT
# T19	Process 880 895	closed form EoS
# T20	Material 1431 1436	beads
# T21	Material 1620 1638	isotropic molecule
# T22	Material 1704 1709	fluid
# T23	Material 1936 1949	simple fluids
# T24	Process 947 960	Mie potential
# T25	Process 985 1000	(m,n) potential
# *	Synonym-of T24 T25
# T26	Process 1028 1040	LJ potential
# R11	Hyponym-of Arg1:T25 Arg2:T26
# T27	Process 1079 1092	Mie potential
# T28	Material 1329 1333	bead
#
#
# 46 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 117 122	water
# T2	KEYPHRASE 207 246	help of 1560nm femtosecond laser pulses
# T3	KEYPHRASE 379 403	femtosecond laser pulses
# T4	KEYPHRASE 474 510	excited molecules undergo relaxation
# T5	KEYPHRASE 519 542	non-radiative processes
# T6	KEYPHRASE 564 589	transient thermal effects
# T7	KEYPHRASE 597 622	transient thermal effects
# T8	KEYPHRASE 642 682	pure optical nonlinearity of the samples
# T9	KEYPHRASE 744 769	transient thermal effects
# T10	KEYPHRASE 818 840	repetition-rate lasers
# T11	KEYPHRASE 844 879	produce a cumulative thermal effect
# T12	KEYPHRASE 953 1000	mode-mismatched two-color pump–probe experiment
#
#   +++ KLEIS +++
#
# T21	KEYPHRASE 117 122	water
# T23	KEYPHRASE 156 157	β
# T35	KEYPHRASE 500 510	relaxation
# T61	KEYPHRASE 351 359	alcohols
# T68	KEYPHRASE 675 682	samples
# T74	KEYPHRASE 953 1000	mode-mismatched two-color pump–probe experiment
# T110	KEYPHRASE 474 491	excited molecules
# T111	KEYPHRASE 519 542	non-radiative processes
#
#   +++ RAW +++
#
# T1	Process 22 49	aperture Z-scan experiments
# T2	Material 215 246	1560nm femtosecond laser pulses
# T3	Material 292 307	optical-chopper
# T4	Process 313 343	vibrational combination states
# T5	Process 519 542	non-radiative processes
# T6	Process 564 589	transient thermal effects
# T7	Task 905 943	measure this cumulative thermal effect
# T8	Process 953 1000	mode-mismatched two-color pump–probe experiment
# T9	Material 379 413	femtosecond laser pulses at 1560nm
# T10	Process 597 622	transient thermal effects
# T11	Process 642 667	pure optical nonlinearity
# T12	Process 744 769	transient thermal effects
# T13	Process 854 879	cumulative thermal effect
# T14	Material 117 122	water
# T15	Task 69 90	saturation absorption
# T16	Material 181 197	primary alcohols
# T17	Material 351 359	alcohols
# T18	Material 482 491	molecules
# T19	Process 445 455	absorption
# T20	Material 813 840	high repetition-rate lasers
#
#
# 47 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 26 53	optical properties of atoms
# T2	KEYPHRASE 95 117	electronic environment
# T3	KEYPHRASE 119 138	Local field effects
# T4	KEYPHRASE 142 168	spontaneous emission rates
# T5	KEYPHRASE 176 209	nanostructured photonic materials
# T6	KEYPHRASE 271 288	Optical processes
# T7	KEYPHRASE 300 325	resonance energy transfer
# T8	KEYPHRASE 378 400	molecular chromophores
# T9	KEYPHRASE 413 431	biological systems
# T10	KEYPHRASE 453 509	complex organizations of molecules with absorption bands
# T11	KEYPHRASE 529 549	electronic influence
# T12	KEYPHRASE 560 582	nearby optical centres
# T13	KEYPHRASE 684 735	photosynthetic antenna molecule bacteriochlorophyll
# T14	KEYPHRASE 742 758	absorption bands
# T15	KEYPHRASE 891 922	neighbouring carotenoid species
# T16	KEYPHRASE 1018 1035	photon absorption
# T17	KEYPHRASE 1076 1102	induced circular dichroism
# T18	KEYPHRASE 1115 1156	quantum electrodynamic (QED) calculations
# T19	KEYPHRASE 1168 1191	experimental procedures
# T20	KEYPHRASE 1226 1249	chiral mediator confers
# T21	KEYPHRASE 1270 1286	achiral acceptor
#
#   +++ KLEIS +++
#
# T19	KEYPHRASE 1018 1035	photon absorption
# T24	KEYPHRASE 214 221	example
# T31	KEYPHRASE 588 596	instance
# T42	KEYPHRASE 978 990	neighbouring
# T43	KEYPHRASE 1006 1014	molecule
# T44	KEYPHRASE 1018 1024	photon
# T46	KEYPHRASE 1062 1072	phenomenon
# T47	KEYPHRASE 1093 1102	dichroism
# T56	KEYPHRASE 300 325	resonance energy transfer
# T61	KEYPHRASE 1139 1142	QED
# T66	KEYPHRASE 1076 1102	induced circular dichroism
# T69	KEYPHRASE 48 53	atoms
# T70	KEYPHRASE 58 67	molecules
# T78	KEYPHRASE 478 487	molecules
# T90	KEYPHRASE 271 288	Optical processes
# T141	KEYPHRASE 378 400	molecular chromophores
# T169	KEYPHRASE 560 582	nearby optical centres
#
#   +++ RAW +++
#
# T1	Task 26 44	optical properties
# T2	Process 95 117	electronic environment
# T3	Process 271 288	Optical processes
# T4	Process 300 325	resonance energy transfer
# R1	Hyponym-of Arg1:T4 Arg2:T3
# T5	Material 493 509	absorption bands
# T6	Process 529 549	electronic influence
# T7	Process 1115 1137	quantum electrodynamic
# T8	Process 1139 1142	QED
# *	Synonym-of T8 T7
# T9	Process 1168 1191	experimental procedures
# T10	Process 357 400	local environment of molecular chromophores
# T11	Process 616 642	light-harvesting complexes
# T12	Material 684 735	photosynthetic antenna molecule bacteriochlorophyll
# T13	Material 742 758	absorption bands
# T14	Process 836 851	energy transfer
# T15	Task 963 1035	influence of a neighbouring, off-resonant, molecule on photon absorption
# T16	Process 1076 1102	induced circular dichroism
# T17	Process 1298 1330	circular differential absorption
# T18	Material 48 53	atoms
# T19	Material 58 67	molecules
# T20	Process 119 138	Local field effects
# T21	Material 176 209	nanostructured photonic materials
# T22	Material 904 922	carotenoid species
# T23	Process 1018 1035	photon absorption
# T24	Material 1006 1014	molecule
# T25	Material 1018 1024	photon
# T26	Material 1226 1241	chiral mediator
# T27	Material 1270 1286	achiral acceptor
#
#
# 48 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 298 310	fuel storage
# T2	KEYPHRASE 426 464	pellet cladding mechanical interaction
# T3	KEYPHRASE 466 470	PCMI
# T4	KEYPHRASE 476 496	introduce mechanisms
# T5	KEYPHRASE 518 542	delayed hydride cracking
# T6	KEYPHRASE 544 547	DHC
# T7	KEYPHRASE 554 570	former mechanism
# T8	KEYPHRASE 578 606	product of thermal expansion
# T9	KEYPHRASE 610 643	fuel pellets introducing stresses
# T10	KEYPHRASE 774 790	latter mechanism
# T11	KEYPHRASE 792 795	DHC
# T12	KEYPHRASE 876 928	hydrogen diffusion for repeated local hydride growth
# T13	KEYPHRASE 947 980	hydrostatic tensile stress raiser
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 117 133	tensile strength
# T2	KEYPHRASE 442 464	mechanical interaction
# T4	KEYPHRASE 554 570	former mechanism
# T5	KEYPHRASE 589 606	thermal expansion
# T6	KEYPHRASE 774 790	latter mechanism
# T12	KEYPHRASE 298 310	fuel storage
# T21	KEYPHRASE 31 40	zirconium
# T22	KEYPHRASE 81 90	component
# T24	KEYPHRASE 135 144	ductility
# T25	KEYPHRASE 149 157	fracture
# T37	KEYPHRASE 501 508	failure
# T44	KEYPHRASE 653 661	cladding
# T56	KEYPHRASE 933 941	fracture
# T61	KEYPHRASE 996 1003	process
# T70	KEYPHRASE 518 542	delayed hydride cracking
# T77	KEYPHRASE 466 470	PCMI
# T78	KEYPHRASE 544 547	DHC
# T79	KEYPHRASE 792 795	DHC
# T86	KEYPHRASE 386 394	hydrides
# T91	KEYPHRASE 703 709	cracks
# T95	KEYPHRASE 947 980	hydrostatic tensile stress raiser
# T102	KEYPHRASE 610 622	fuel pellets
# T133	KEYPHRASE 332 368	degradation of mechanical properties
# T163	KEYPHRASE 1051 1076	continuously applied load
# T212	KEYPHRASE 589 622	thermal expansion in fuel pellets
#
#   +++ RAW +++
#
# T1	Material 0 8	Hydrides
# T2	Material 31 40	zirconium
# T3	Process 234 242	cladding
# T4	Material 298 302	fuel
# T5	Material 526 533	hydride
# T6	Material 386 394	hydrides
# T7	Process 426 464	pellet cladding mechanical interaction
# T8	Process 466 470	PCMI
# *	Synonym-of T7 T8
# T9	Process 518 542	delayed hydride cracking
# T10	Process 544 547	DHC
# *	Synonym-of T9 T10
# T11	Process 589 606	thermal expansion
# T12	Material 610 622	fuel pellets
# T13	Process 653 661	cladding
# T14	Material 741 748	hydride
# T15	Process 792 795	DHC
# T16	Process 831 850	cracking phenomenon
# R1	Hyponym-of Arg1:T15 Arg2:T16
# T17	Material 876 884	hydrogen
# T18	Process 876 894	hydrogen diffusion
# T19	Task 908 928	local hydride growth
# T20	Process 947 980	hydrostatic tensile stress raiser
# T21	Material 433 441	cladding
#
#
# 49 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 32 35	RCS
# T2	KEYPHRASE 52 55	RCS
# T3	KEYPHRASE 103 127	ferritic stainless steel
# T4	KEYPHRASE 217 232	diverse hazards
# T5	KEYPHRASE 462 513	corrosion and the presence of manufacturing defects
# T6	KEYPHRASE 515 543	Human factor induced defects
# T7	KEYPHRASE 695 714	excessive vibration
# T8	KEYPHRASE 873 905	non-appropriate choice of alloys
# T9	KEYPHRASE 940 959	chemical parameters
# T10	KEYPHRASE 967 972	fluid
# T11	KEYPHRASE 987 1008	Manufacturing defects
# T12	KEYPHRASE 1075 1127	design documentation during post-weld heat treatment
#
#   +++ KLEIS +++
#
# T3	KEYPHRASE 234 252	mechanical fatigue
# T7	KEYPHRASE 695 714	excessive vibration
# T13	KEYPHRASE 1075 1095	design documentation
# T17	KEYPHRASE 122 127	steel
# T25	KEYPHRASE 420 427	failure
# T27	KEYPHRASE 462 471	corrosion
# T36	KEYPHRASE 772 776	pipe
# T37	KEYPHRASE 823 832	Corrosion
# T41	KEYPHRASE 967 972	fluid
# T42	KEYPHRASE 1056 1065	deviation
# T51	KEYPHRASE 32 35	RCS
# T52	KEYPHRASE 52 55	RCS
# T63	KEYPHRASE 390 395	leaks
# T72	KEYPHRASE 814 821	factors
# T74	KEYPHRASE 899 905	alloys
# T76	KEYPHRASE 980 985	pipes
# T139	KEYPHRASE 480 513	presence of manufacturing defects
#
#   +++ RAW +++
#
# T1	Material 4 9	pipes
# T2	Material 32 35	RCS
# T3	Material 52 55	RCS
# T4	Material 76 127	austenitic or austenitic & ferritic stainless steel
# T5	Material 162 167	pipes
# T6	Material 772 776	pipe
# T7	Material 967 972	fluid
# T8	Material 980 985	pipes
# T9	Task 296 311	Event screening
# T10	Material 899 905	alloys
#
#
# 50 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 49 70	intermediate radicals
# T2	KEYPHRASE 96 111	reducing agents
# T3	KEYPHRASE 216 230	reducing agent
# T4	KEYPHRASE 253 256	CO2
# T5	KEYPHRASE 274 322	formic acid or methanol with suitable catalyzers
# T6	KEYPHRASE 418 465	theoretically predicted dissociation thresholds
# T7	KEYPHRASE 478 481	AOH
# T8	KEYPHRASE 486 498	BAH radicals
# T9	KEYPHRASE 570 627	predicted dissociation threshold of the pyridinyl radical
# T10	KEYPHRASE 811 850	reduce carbon dioxide in dark reactions
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 76 82	latter
# T10	KEYPHRASE 281 285	acid
# T11	KEYPHRASE 289 297	methanol
# T21	KEYPHRASE 788 794	latter
# T22	KEYPHRASE 818 824	carbon
# T27	KEYPHRASE 184 187	PyH
# T28	KEYPHRASE 253 256	CO2
# T30	KEYPHRASE 478 481	AOH
# T37	KEYPHRASE 312 322	catalyzers
# T38	KEYPHRASE 363 372	reactions
# T43	KEYPHRASE 718 727	acridinyl
# T71	KEYPHRASE 836 850	dark reactions
# T143	KEYPHRASE 478 498	AOH and BAH radicals
#
#   +++ RAW +++
#
# T1	Process 17 39	H-atom photodetachment
# T2	Material 49 70	intermediate radicals
# T3	Material 96 111	reducing agents
# R1	Hyponym-of Arg1:T2 Arg2:T3
# T4	Material 165 182	pyridinyl radical
# T5	Material 184 187	PyH
# *	Synonym-of T4 T5
# T6	Material 216 230	reducing agent
# R2	Hyponym-of Arg1:T5 Arg2:T6
# T7	Material 253 256	CO2
# T8	Material 260 272	formaldehyde
# T9	Material 274 285	formic acid
# T10	Material 289 297	methanol
# T11	Material 312 322	catalyzers
# T12	Material 473 498	AcH, AOH and BAH radicals
# T13	Material 610 627	pyridinyl radical
# T14	Material 660 669	Pyridinyl
# T15	Material 718 727	acridinyl
# T16	Material 740 748	radicals
# R3	Hyponym-of Arg1:T15 Arg2:T16
# T17	Material 703 712	reductant
# R4	Hyponym-of Arg1:T14 Arg2:T17
# R5	Hyponym-of Arg1:T15 Arg2:T17
# T18	Task 811 850	reduce carbon dioxide in dark reactions
# T19	Material 818 832	carbon dioxide

# %%
default_corpus.load_test()

# %%
import os
output = 'output-baseline/test/'
if not kd.path_exists(output):
    os.makedirs(output)
    
for i, (key, tmp_dataset) in enumerate(default_corpus.test.items()):
    text = tmp_dataset["raw"]["txt"]
    tags = tmp_dataset["tags"]
    X_test = [kd.simple_features(tag, i, len(tags), [], []) for i, tag in enumerate(tags)]
    # print(tags)
    keyphrases_kleis = default_corpus.label_text(text)
    keyphrases = []
    keyphrases_labels = tagger.tag(X_test)
    tid = 0
    for token_index, label in enumerate(keyphrases_labels):
        if label == 'O':
            continue
        else:
            if label[:2] == 'U-':
                tid += 1
                keyphrase = None
                token_start = min(tags[token_index][2])
                token_end = max(tags[token_index][2])
                keyphrase = ("T%d" % tid, ("KEYPHRASE", (token_start, token_end)), text[token_start:token_end])
                keyphrases.append(keyphrase)
                
            if label[:2] == 'B-':
                tid += 1
                token_start = min(tags[token_index][2])
                token_end = max(tags[token_index][2])
                keyphrase = ("T%d" % tid, ("KEYPHRASE", (token_start, token_end)), text[token_start:token_end])
                
            if label[:2] == 'I-':
                token_end = max(tags[token_index][2])
                kp_id, (kp_label, (kp_start, _)), _ = keyphrase
                keyphrase = (kp_id, (kp_label, (kp_start, token_end)), text[kp_start:token_end])

            if label[:2] == 'L-':
                token_end = max(tags[token_index][2])
                kp_id, (kp_label, (kp_start, _)), _ = keyphrase
                keyphrases.append((kp_id, (kp_label, (kp_start, token_end)), text[kp_start:token_end]))
                keyphrase = None

    #print("\n".join([str(kp) for kp in keyphrases]))
    print("\n%d ----" % (i+1))
    print("\n  +++ CRF +++ \n")  
    print(kd.keyphrases2brat(keyphrases))
    print("\n  +++ KLEIS +++ \n")  
    print(kd.keyphrases2brat(keyphrases_kleis))
    print("\n  +++ RAW +++ \n") 
    print(tmp_dataset["raw"]["ann"])
    with open(output + key + ".ann", "w", encoding="utf-8") as fout:
        fout.write(kd.keyphrases2brat(keyphrases))
    with open(output + key + ".txt", "w", encoding="utf-8") as fout:
        fout.write(text)
    # print(keyphrases)
# Out:
# 1 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 87 115	nx unknown nodal coordinates
# T2	KEYPHRASE 133 173	nb unknown discrete Lagrange multipliers
# T3	KEYPHRASE 179 193	linear systems
# T4	KEYPHRASE 228 249	Newton-based solution
# T5	KEYPHRASE 359 425	tangent stiffness matrix of the unconstrained pseudo-solid problem
# T6	KEYPHRASE 439 458	off-diagonal blocks
# T7	KEYPHRASE 603 639	LBB stability of this discretisation
# T8	KEYPHRASE 682 772	LBB stability of the Lagrange-multiplier-based imposition of Dirichlet boundary conditions
# T9	KEYPHRASE 836 852	Newton iteration
# T10	KEYPHRASE 859 886	symmetric positive definite
# T11	KEYPHRASE 911 958	tangent stiffness matrix relative to the system
# T12	KEYPHRASE 961 986	equilibrium configuration
#
#   +++ KLEIS +++
#
# T23	KEYPHRASE 350 351	E
# T33	KEYPHRASE 625 639	discretisation
# T49	KEYPHRASE 836 852	Newton iteration
# T53	KEYPHRASE 70 71	L
# T64	KEYPHRASE 854 855	E
# T71	KEYPHRASE 53 61	unknowns
# T109	KEYPHRASE 179 193	linear systems
#
#   +++ RAW +++
#
# T1	Material 43 61	vector of unknowns
# T2	Material 63 72	xPS=[X,L]
# *	Synonym-of T1 T2
# T3	Material 98 115	nodal coordinates
# T4	Material 153 173	Lagrange multipliers
# T5	Process 228 249	Newton-based solution
# T6	Material 278 301	displacement constraint
# T7	Process 317 339	saddle-point structure
# T8	Process 359 383	tangent stiffness matrix
# T9	Material 391 425	unconstrained pseudo-solid problem
# T10	Material 435 458	two off-diagonal blocks
# T11	Material 459 462	Cxl
# T12	Material 467 475	Clx=CxlT
# R1	Hyponym-of Arg1:T11 Arg2:T10
# R2	Hyponym-of Arg1:T12 Arg2:T10
# T13	Material 543 563	Lagrange multipliers
# T14	Process 743 772	Dirichlet boundary conditions
# T15	Process 836 852	Newton iteration
# T16	Process 961 986	equilibrium configuration
# T17	Task 3 30	order the discrete unknowns
# T18	Material 911 935	tangent stiffness matrix
# T19	Process 625 639	discretisation
# T20	Material 603 606	LBB
# T21	Material 682 685	LBB
# T22	Process 703 739	Lagrange-multiplier-based imposition
#
#
# 2 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 22 85	theory of electrons carrying quantized orbital angular momentum
# T2	KEYPHRASE 109 129	realistic situations
# T3	KEYPHRASE 147 202	plane wave moving along the optic axis of a lens system
# T4	KEYPHRASE 293 309	holographic mask
# T5	KEYPHRASE 389 417	reduced Schrödinger equation
# T6	KEYPHRASE 476 506	Bessel's differential equation
# T7	KEYPHRASE 559 595	discrete orbital angular momentum ℏm
# T8	KEYPHRASE 700 710	plane wave
# T9	KEYPHRASE 735 751	holographic mask
# T10	KEYPHRASE 759 775	fork dislocation
# T11	KEYPHRASE 805 824	cylindrical problem
# T12	KEYPHRASE 854 908	magnetic lenses into volcano-like charge distributions
# T13	KEYPHRASE 957 970	loop currents
# T14	KEYPHRASE 978 995	diffraction plane
# T15	KEYPHRASE 997 1030	Inclusion of spherical aberration
# T16	KEYPHRASE 1071 1117	destroy the central zero intensity of vortices
# T17	KEYPHRASE 1128 1166	Partial coherence of the incident wave
# T18	KEYPHRASE 1403 1452	creation of nm-sized or smaller electron vortices
#
#   +++ KLEIS +++
#
# T4	KEYPHRASE 293 309	holographic mask
# T10	KEYPHRASE 735 751	holographic mask
# T11	KEYPHRASE 805 824	cylindrical problem
# T28	KEYPHRASE 978 995	diffraction plane
# T36	KEYPHRASE 95 105	connection
# T41	KEYPHRASE 221 226	round
# T42	KEYPHRASE 255 265	experiment
# T55	KEYPHRASE 623 624	m
# T60	KEYPHRASE 717 724	passage
# T74	KEYPHRASE 1123 1126	m≠0
# T101	KEYPHRASE 875 908	volcano-like charge distributions
# T106	KEYPHRASE 32 41	electrons
# T116	KEYPHRASE 1109 1117	vortices
# T234	KEYPHRASE 389 427	reduced Schrödinger equation operating
#
#   +++ RAW +++
#
# T1	Process 32 86	electrons carrying quantized orbital angular momentum.
# T2	Material 147 157	plane wave
# T3	Material 191 202	lens system
# T4	Process 389 417	reduced Schrödinger equation
# T5	Material 661 669	vortices
# T7	Process 997 1030	Inclusion of spherical aberration
# T8	Process 1403 1452	creation of nm-sized or smaller electron vortices
# T10	Material 221 245	round, centered aperture
# T11	Material 272 280	aperture
# T12	Material 293 309	holographic mask
# T13	Material 448 456	aperture
# T14	Material 435 440	plane
# T15	Material 700 710	plane wave
# T16	Material 735 751	holographic mask
# T17	Process 926 944	angular divergence
# T18	Material 854 869	magnetic lenses
# T6	Process 1128 1145	Partial coherence
# T9	Material 1153 1166	incident wave
#
#
# 3 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 38	proposed multihop routing protocol
# T2	KEYPHRASE 95 99	MWSN
# T3	KEYPHRASE 293 309	dynamic topology
# T4	KEYPHRASE 347 377	flooding or location awareness
# T5	KEYPHRASE 387 464	flooding creates large amounts of overhead and location determination schemes
# T6	KEYPHRASE 563 575	novel method
# T7	KEYPHRASE 605 619	mobile network
# T8	KEYPHRASE 640 692	proactive sharing of only local topology information
# T9	KEYPHRASE 719 761	global TDMA (time division multiple access
# T10	KEYPHRASE 763 766	MAC
# T11	KEYPHRASE 768 796	medium access control) layer
# T12	KEYPHRASE 860 883	decrease packet latency
# T13	KEYPHRASE 962 976	multiple nodes
# T14	KEYPHRASE 1070 1086	node cooperation
# T15	KEYPHRASE 1090 1132	create a robust multipath routing solution
# T16	KEYPHRASE 1179 1207	cross-layer routing protocol
# T17	KEYPHRASE 1212 1217	MWSNs
# T18	KEYPHRASE 1227 1259	handle the constant flow of data
# T19	KEYPHRASE 1265 1272	sensors
# T20	KEYPHRASE 1283 1300	mobile situations
#
#   +++ KLEIS +++
#
# T38	KEYPHRASE 359 367	location
# T40	KEYPHRASE 421 429	overhead
# T56	KEYPHRASE 755 761	access
# T61	KEYPHRASE 831 839	overhead
# T62	KEYPHRASE 850 854	turn
# T66	KEYPHRASE 924 937	encapsulation
# T69	KEYPHRASE 1049 1056	traffic
# T72	KEYPHRASE 1124 1132	solution
# T80	KEYPHRASE 768 789	medium access control
# T82	KEYPHRASE 40 46	PHASeR
# T83	KEYPHRASE 95 99	MWSN
# T84	KEYPHRASE 549 555	PHASeR
# T86	KEYPHRASE 763 766	MAC
# T87	KEYPHRASE 885 891	PHASeR
# T88	KEYPHRASE 1212 1217	MWSNs
# T90	KEYPHRASE 187 193	routes
# T99	KEYPHRASE 1265 1272	sensors
# T147	KEYPHRASE 434 464	location determination schemes
#
#   +++ RAW +++
#
# T1	Process 13 38	multihop routing protocol
# T2	Process 40 46	PHASeR
# *	Synonym-of T1 T2
# T3	Material 95 99	MWSN
# T4	Process 220 235	gradient metric
# T5	Task 13 38	multihop routing protocol
# T6	Process 549 555	PHASeR
# T7	Process 579 599	gradient maintenance
# T8	Material 605 619	mobile network
# T9	Process 726 730	TDMA
# T10	Process 732 761	time division multiple access
# *	Synonym-of T9 T10
# T11	Process 763 766	MAC
# T12	Process 768 789	medium access control
# *	Synonym-of T11 T12
# T13	Material 869 883	packet latency
# T14	Process 885 891	PHASeR
# T15	Process 924 937	encapsulation
# T16	Process 1179 1207	cross-layer routing protocol
# T17	Material 1212 1217	MWSNs
# T18	Process 1070 1086	node cooperation
# T19	Material 1070 1074	node
# T20	Material 971 976	nodes
# T21	Material 1265 1272	sensors
# T22	Task 1179 1217	cross-layer routing protocol for MWSNs
#
#
# 4 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 89 120	time–frequency analysis methods
# T2	KEYPHRASE 126 142	STFT spectrogram
# T3	KEYPHRASE 281 300	spectrogram suffers
# T4	KEYPHRASE 308 324	fixed resolution
# T5	KEYPHRASE 436 459	time–frequency analysis
# T6	KEYPHRASE 478 494	wavelet analysis
# T7	KEYPHRASE 522 547	multi-resolution analysis
# T8	KEYPHRASE 571 623	temporal resolution of the high frequency components
# T9	KEYPHRASE 629 681	frequency resolution of the low frequency components
# T10	KEYPHRASE 737 745	SH waves
# T11	KEYPHRASE 768 773	EMATs
# T12	KEYPHRASE 806 825	pulsed array system
# T13	KEYPHRASE 969 998	longitudinal ultrasonic waves
# T14	KEYPHRASE 1002 1023	electromagnetic waves
#
#   +++ KLEIS +++
#
# T13	KEYPHRASE 397 417	frequency resolution
# T14	KEYPHRASE 436 459	time–frequency analysis
# T16	KEYPHRASE 522 547	multi-resolution analysis
# T42	KEYPHRASE 496 503	benefit
# T56	KEYPHRASE 908 918	phenomenon
# T60	KEYPHRASE 469 494	discrete wavelet analysis
# T61	KEYPHRASE 806 825	pulsed array system
# T62	KEYPHRASE 126 142	STFT spectrogram
# T66	KEYPHRASE 768 773	EMATs
# T67	KEYPHRASE 598 623	high frequency components
# T68	KEYPHRASE 657 681	low frequency components
# T80	KEYPHRASE 857 862	waves
# T82	KEYPHRASE 993 998	waves
# T84	KEYPHRASE 737 745	SH waves
# T118	KEYPHRASE 1002 1023	electromagnetic waves
# T124	KEYPHRASE 89 120	time–frequency analysis methods
# T137	KEYPHRASE 969 998	longitudinal ultrasonic waves
#
#   +++ RAW +++
#
# T1	Task 76 120	use of other time–frequency analysis methods
# T2	Process 126 142	STFT spectrogram
# T5	Process 436 459	time–frequency analysis
# T6	Process 469 494	discrete wavelet analysis
# T7	Process 522 547	multi-resolution analysis
# T8	Material 571 590	temporal resolution
# T9	Material 629 649	frequency resolution
# T10	Material 737 745	SH waves
# T11	Process 768 773	EMATs
# T12	Material 969 998	longitudinal ultrasonic waves
# T13	Material 1002 1023	electromagnetic waves
# T14	Process 89 112	time–frequency analysis
# T3	Process 281 292	spectrogram
# R1	Hyponym-of Arg1:T6 Arg2:T5
# T4	Material 397 417	frequency resolution
# T15	Material 308 324	fixed resolution
# T16	Material 346 361	time resolution
# T17	Material 657 681	low frequency components
# T18	Material 806 825	pulsed array system
# T19	Task 889 949	demonstrating this phenomenon with a number of other systems
#
#
# 5 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 32 100	high-order discretisation retains exponential convergence properties
# T2	KEYPHRASE 106 140	increasing geometric and expansion
# T3	KEYPHRASE 298 314	surface elements
# T4	KEYPHRASE 325 373	dominate the temporal and spatial discretisation
# T5	KEYPHRASE 622 648	solution polynomial orders
# T6	KEYPHRASE 678 702	geometry parametrisation
# T7	KEYPHRASE 736 755	analytic test cases
# T8	KEYPHRASE 777 800	coarse curvilinear mesh
# T9	KEYPHRASE 1371 1394	geometric approximation
# T10	KEYPHRASE 1446 1461	cardiac problem
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 32 57	high-order discretisation
# T6	KEYPHRASE 596 611	mesh refinement
# T11	KEYPHRASE 1126 1138	true surface
# T16	KEYPHRASE 678 702	geometry parametrisation
# T25	KEYPHRASE 170 178	solution
# T26	KEYPHRASE 188 195	surface
# T34	KEYPHRASE 572 579	freedom
# T46	KEYPHRASE 890 898	solution
# T47	KEYPHRASE 930 938	geometry
# T51	KEYPHRASE 1010 1018	solution
# T54	KEYPHRASE 1098 1106	solution
# T55	KEYPHRASE 1131 1138	surface
# T58	KEYPHRASE 1336 1347	convergence
# T60	KEYPHRASE 1411 1418	surface
# T64	KEYPHRASE 1501 1509	solution
# T65	KEYPHRASE 777 800	coarse curvilinear mesh
# T66	KEYPHRASE 1181 1182	P
# T86	KEYPHRASE 820 826	meshes
# T184	KEYPHRASE 275 314	parametrisation of the surface elements
#
#   +++ RAW +++
#
# T1	Process 32 57	high-order discretisation
# T2	Process 66 100	exponential convergence properties
# T4	Process 275 314	parametrisation of the surface elements
# T6	Process 596 611	mesh refinement
# T7	Process 615 648	higher solution polynomial orders
# T8	Process 715 730	geometric error
# T9	Material 777 800	coarse curvilinear mesh
# T11	Process 956 979	reduce this lower bound
# T14	Process 1152 1175	exponential convergence
# T15	Material 1265 1283	element boundaries
# T16	Process 1232 1283	discontinuities are aligned with element boundaries
# T17	Material 1327 1334	element
# T18	Process 1371 1394	geometric approximation
# T19	Task 1446 1461	cardiac problem
# T20	Material 820 826	meshes
# T3	Material 170 178	solution
# T21	Material 183 195	true surface
# T22	Material 298 314	surface elements
# T5	Material 390 406	smooth solutions
# T23	Process 678 702	geometry parametrisation
# T24	Task 736 755	analytic test cases
# R1	Hyponym-of Arg1:T9 Arg2:T20
# T25	Material 890 898	solution
# T10	Material 987 995	solution
# T12	Material 1010 1018	solution
# T13	Material 1098 1106	solution
# T26	Material 1484 1496	true surface
# T27	Material 1501 1509	solution
# T28	Material 1406 1418	true surface
# T29	Material 1126 1138	true surface
# T30	Process 866 898	capture features in the solution
# T31	Process 918 938	capture the geometry
# T32	Material 1181 1182	P
# T33	Material 1187 1189	Pg
#
#
# 6 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 72	Production of charmonium states J/ψ and ψ′ in nucleus–nucleus collisions
# T2	KEYPHRASE 98 101	SPS
# T3	KEYPHRASE 136 140	NA38
# T4	KEYPHRASE 145 164	NA50 Collaborations
# T5	KEYPHRASE 299 327	early stage of the collision
# T6	KEYPHRASE 443 472	initial stage of the reaction
# T7	KEYPHRASE 484 510	nucleon–nucleon collisions
# T8	KEYPHRASE 580 592	charm mesons
# T9	KEYPHRASE 620 665	absorption of pre-resonance charmonium states
# T10	KEYPHRASE 669 685	nuclear nucleons
# T11	KEYPHRASE 694 713	nuclear suppression
# T12	KEYPHRASE 785 817	dissociation of cc̄ bound states
# T13	KEYPHRASE 821 838	deconfined medium
# T14	KEYPHRASE 840 861	anomalous suppression
# T15	KEYPHRASE 886 901	J/ψ suppression
# T16	KEYPHRASE 918 938	Drell–Yan muon pairs
# T17	KEYPHRASE 970 996	nucleus–nucleus collisions
# T18	KEYPHRASE 1002 1019	light projectiles
# T19	KEYPHRASE 1071 1109	sweeping nucleons) nuclear suppression
# T20	KEYPHRASE 1134 1149	NA50 experiment
# T21	KEYPHRASE 1157 1261	heavy projectile and target (Pb+Pb) revealed essentially stronger J/ψ suppression for central collisions
# T22	KEYPHRASE 1274 1299	anomalous J/ψ suppression
# T23	KEYPHRASE 1318 1349	formation of quark–gluon plasma
# T24	KEYPHRASE 1351 1354	QGP
#
#   +++ KLEIS +++
#
# T9	KEYPHRASE 821 838	deconfined medium
# T12	KEYPHRASE 1157 1173	heavy projectile
# T15	KEYPHRASE 1331 1349	quark–gluon plasma
# T21	KEYPHRASE 14 24	charmonium
# T23	KEYPHRASE 220 230	suggestion
# T29	KEYPHRASE 318 327	collision
# T34	KEYPHRASE 402 411	charmonia
# T36	KEYPHRASE 464 472	reaction
# T38	KEYPHRASE 551 557	system
# T45	KEYPHRASE 717 718	b
# T46	KEYPHRASE 736 745	charmonia
# T47	KEYPHRASE 782 783	c
# T48	KEYPHRASE 785 797	dissociation
# T66	KEYPHRASE 1331 1342	quark–gluon
# T74	KEYPHRASE 1134 1149	NA50 experiment
# T81	KEYPHRASE 136 140	NA38
# T93	KEYPHRASE 1351 1354	QGP
# T94	KEYPHRASE 573 592	hidden charm mesons
# T100	KEYPHRASE 586 592	mesons
# T105	KEYPHRASE 770 778	comovers
# T151	KEYPHRASE 46 72	nucleus–nucleus collisions
# T153	KEYPHRASE 669 685	nuclear nucleons
# T156	KEYPHRASE 1002 1019	light projectiles
# T158	KEYPHRASE 1243 1261	central collisions
# T170	KEYPHRASE 918 938	Drell–Yan muon pairs
# T174	KEYPHRASE 801 817	cc̄ bound states
# T191	KEYPHRASE 476 510	primary nucleon–nucleon collisions
# T260	KEYPHRASE 1274 1299	anomalous J/ψ suppression
# T263	KEYPHRASE 951 996	proton–nucleus and nucleus–nucleus collisions
#
#   +++ RAW +++
#
# T1	Material 14 31	charmonium states
# T2	Task 171 191	experimental program
# T3	Material 333 349	original picture
# T4	Process 523 558	subsequent evolution of the system,
# T5	Material 573 592	hidden charm mesons
# T6	Process 620 685	absorption of pre-resonance charmonium states by nuclear nucleons
# T7	Process 720 768	interactions of charmonia with secondary hadrons
# T8	Process 785 838	dissociation of cc̄ bound states in deconfined medium
# T9	Process 886 901	J/ψ suppression
# T10	Material 951 965	proton–nucleus
# T11	Process 970 996	nucleus–nucleus collisions
# T12	Material 1002 1019	light projectiles
# T13	Task 1134 1149	NA50 experiment
# T14	Process 1284 1299	J/ψ suppression
# T15	Process 1318 1349	formation of quark–gluon plasma
# T16	Process 1367 1383	comover scenario
# T18	Material 246 249	J/ψ
# T19	Material 402 411	charmonia
# T20	Process 476 510	primary nucleon–nucleon collisions
# T21	Material 669 685	nuclear nucleons
# T22	Process 770 778	comovers
# T23	Process 840 861	anomalous suppression
# T24	Process 1090 1109	nuclear suppression
# T25	Material 1071 1088	sweeping nucleons
# T26	Material 1186 1191	Pb+Pb
# T17	Material 32 35	J/ψ
# T27	Material 40 42	ψ′
# R1	Hyponym-of Arg1:T17 Arg2:T1
# R2	Hyponym-of Arg1:T27 Arg2:T1
# T28	Process 46 72	nucleus–nucleus collisions
# T29	Material 46 53	nucleus
# T30	Material 54 61	nucleus
# T31	Task 0 72	Production of charmonium states J/ψ and ψ′ in nucleus–nucleus collisions
# T32	Task 238 327	use the J/ψ as a probe of the state of matter created at the early stage of the collision
# T33	Material 484 491	nucleon
# T34	Material 492 499	nucleon
# T35	Process 687 713	normal nuclear suppression
# *	Synonym-of T35 T6
# T36	Material 736 745	charmonia
# T37	Material 761 768	hadrons
# *	Synonym-of T22 T7
# T38	Material 648 658	charmonium
# *	Synonym-of T8 T23
# T39	Material 801 804	cc̄
# T40	Material 886 889	J/ψ
# T41	Material 918 938	Drell–Yan muon pairs
# T42	Material 978 985	nucleus
# T43	Material 970 977	nucleus
# T44	Material 1223 1226	J/ψ
# T45	Material 1157 1184	heavy projectile and target
# R3	Hyponym-of Arg1:T26 Arg2:T45
# T46	Process 1223 1238	J/ψ suppression
# T47	Process 1243 1261	central collisions
# T48	Material 1284 1287	J/ψ
# T49	Material 1331 1349	quark–gluon plasma
# T50	Material 1351 1354	QGP
# *	Synonym-of T49 T50
#
#
# 7 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 13 28	Focusing Method
# T2	KEYPHRASE 30 33	TFM
# T3	KEYPHRASE 141 149	FMC data
# T4	KEYPHRASE 186 195	x–z plane
# T5	KEYPHRASE 350 397	Linear interpolation of the time domain signals
# T6	KEYPHRASE 467 481	TFM image ITFM
# T7	KEYPHRASE 517 521	ITFM
# T8	KEYPHRASE 575 578	HTR
# T9	KEYPHRASE 589 606	Hilbert transform
# T10	KEYPHRASE 633 641	FMC data
# T11	KEYPHRASE 937 940	FMC
# T12	KEYPHRASE 989 992	TFM
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 612 622	signal uTR
# T7	KEYPHRASE 671 691	transmitting element
# T8	KEYPHRASE 728 745	receiving element
# T9	KEYPHRASE 39 43	beam
# T17	KEYPHRASE 234 238	grid
# T18	KEYPHRASE 277 282	array
# T19	KEYPHRASE 315 320	focus
# T21	KEYPHRASE 344 348	grid
# T28	KEYPHRASE 498 499	z
# T29	KEYPHRASE 524 525	z
# T30	KEYPHRASE 526 532	=|∑HTR
# T31	KEYPHRASE 548 552	xR−x
# T37	KEYPHRASE 643 645	xT
# T46	KEYPHRASE 815 824	summation
# T49	KEYPHRASE 947 956	algorithm
# T58	KEYPHRASE 30 33	TFM
# T64	KEYPHRASE 517 521	ITFM
# T66	KEYPHRASE 537 541	xT−x
# T72	KEYPHRASE 747 748	R
# T74	KEYPHRASE 937 940	FMC
# T78	KEYPHRASE 244 251	signals
# T82	KEYPHRASE 783 791	elements
# T85	KEYPHRASE 141 149	FMC data
# T86	KEYPHRASE 633 641	FMC data
# T105	KEYPHRASE 378 397	time domain signals
# T171	KEYPHRASE 568 578	Rwhere HTR
# T194	KEYPHRASE 7 28	Total Focusing Method
#
#   +++ RAW +++
#
# T1	Process 7 28	Total Focusing Method
# T2	Process 30 33	TFM
# T3	Material 141 149	FMC data
# T4	Process 350 370	Linear interpolation
# T5	Process 467 481	TFM image ITFM
# T6	Process 589 606	Hilbert transform
# T7	Material 671 691	transmitting element
# T8	Material 728 745	receiving element
# T9	Material 937 940	FMC
# T10	Process 976 992	conventional TFM
# T11	Material 186 195	x–z plane
# T12	Material 234 238	grid
# T13	Process 215 238	discretized into a grid
# T14	Process 302 348	synthesize a focus at every point in this grid
# T15	Process 292 298	summed
# T16	Material 344 348	grid
# T17	Process 426 444	discretely sampled
# T18	Material 467 476	TFM image
# T19	Material 633 641	FMC data
# T20	Material 747 748	R
# *	Synonym-of T8 T20
# T21	Material 693 694	T
# *	Synonym-of T7 T21
# T22	Process 815 824	summation
# T23	Material 857 883	transmitter–receiver pairs
#
#
# 8 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 37 39	AD
# T2	KEYPHRASE 139 174	interpretation of experimental data
# T3	KEYPHRASE 215 217	AD
# T4	KEYPHRASE 233 274	electronic structure of realistic systems
# T5	KEYPHRASE 286 301	surface defects
# T6	KEYPHRASE 329 362	electronic structure calculations
# T7	KEYPHRASE 431 450	insulating surfaces
# T8	KEYPHRASE 464 513	model MIES spectra use simple or intuitive models
# T9	KEYPHRASE 561 581	transition mechanism
# T10	KEYPHRASE 585 604	Auger de-excitation
# T11	KEYPHRASE 614 626	MIES spectra
# T12	KEYPHRASE 681 684	DOS
# T13	KEYPHRASE 703 722	surface oxygen ions
# T14	KEYPHRASE 740 753	surface layer
# T15	KEYPHRASE 762 781	Hartree–Fock method
# T16	KEYPHRASE 787 794	crystal
# T17	KEYPHRASE 823 840	functional theory
# T18	KEYPHRASE 842 853	DFT) method
# T19	KEYPHRASE 915 947	surface and He(1s) wavefunctions
# T20	KEYPHRASE 1062 1065	DOS
# T21	KEYPHRASE 1101 1126	AD transition probability
# T22	KEYPHRASE 1135 1138	DOS
# T23	KEYPHRASE 1173 1187	atomic orbital
# T24	KEYPHRASE 1224 1248	state-of-the-art methods
# T25	KEYPHRASE 1257 1285	surface electronic structure
# T26	KEYPHRASE 1354 1367	MIES features
# T27	KEYPHRASE 1497 1500	DOS
#
#   +++ KLEIS +++
#
# T13	KEYPHRASE 561 581	transition mechanism
# T17	KEYPHRASE 787 799	crystal code
# T34	KEYPHRASE 654 661	surface
# T41	KEYPHRASE 787 794	crystal
# T52	KEYPHRASE 915 922	surface
# T53	KEYPHRASE 963 970	account
# T69	KEYPHRASE 556 581	main transition mechanism
# T71	KEYPHRASE 37 47	AD process
# T72	KEYPHRASE 215 224	AD theory
# T75	KEYPHRASE 762 781	Hartree–Fock method
# T84	KEYPHRASE 681 684	DOS
# T86	KEYPHRASE 842 845	DFT
# T89	KEYPHRASE 1135 1138	DOS
# T92	KEYPHRASE 329 362	electronic structure calculations
# T113	KEYPHRASE 1411 1416	peaks
# T115	KEYPHRASE 614 626	MIES spectra
# T124	KEYPHRASE 286 301	surface defects
# T156	KEYPHRASE 157 174	experimental data
# T157	KEYPHRASE 257 274	realistic systems
# T179	KEYPHRASE 703 722	surface oxygen ions
# T186	KEYPHRASE 431 450	insulating surfaces
# T245	KEYPHRASE 233 274	electronic structure of realistic systems
#
#   +++ RAW +++
#
# T1	Material 306 322	adsorbed species
# T2	Material 286 301	surface defects
# T3	Process 815 840	density functional theory
# T4	Process 842 845	DFT
# T5	Process 662 679	density of states
# T6	Process 681 684	DOS
# *	Synonym-of T3 T4 T20
# *	Synonym-of T5 T6
# T7	Material 470 482	MIES spectra
# T8	Process 585 604	Auger de-excitation
# T9	Material 614 626	MIES spectra
# T10	Process 762 781	Hartree–Fock method
# T11	Process 37 39	AD
# T12	Process 215 217	AD
# T13	Process 1062 1065	DOS
# T14	Process 1135 1138	DOS
# T15	Material 1354 1358	MIES
# T16	Process 1497 1500	DOS
# T17	Process 1101 1114	AD transition
# T18	Material 703 722	surface oxygen ions
# T19	Process 787 799	crystal code
# *	Synonym-of T10 T19
# T20	Process 859 869	cetep code
#
#
# 9 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 8 80	physically-based 2D flood models solve the Shallow Water Equations (SWEs
# T2	KEYPHRASE 428 439	JFLOW model
# T3	KEYPHRASE 466 488	Urban Inundation Model
# T4	KEYPHRASE 490 493	UIM
# T5	KEYPHRASE 524 541	diffusive version
# T6	KEYPHRASE 545 556	LISFLOOD-FP
# T7	KEYPHRASE 589 662	2D diffusion wave equations that neglect the inertial (local acceleration
# T8	KEYPHRASE 756 767	LISFLOOD-FP
# T9	KEYPHRASE 817 831	advection term
# T10	KEYPHRASE 843 874	version of LISFLOOD-FP the flow
# T11	KEYPHRASE 895 915	Cartesian directions
# T12	KEYPHRASE 972 994	multi resolution grids
# T13	KEYPHRASE 998 1012	irregular mesh
# T14	KEYPHRASE 1029 1032	ICM
# T15	KEYPHRASE 1054 1078	MIKE FLOOD (DHI Software
# T16	KEYPHRASE 1184 1207	optimisation techniques
# T17	KEYPHRASE 1222 1235	public domain
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 998 1012	irregular mesh
# T15	KEYPHRASE 280 289	reduction
# T23	KEYPHRASE 668 677	advection
# T29	KEYPHRASE 870 874	flow
# T37	KEYPHRASE 428 439	JFLOW model
# T41	KEYPHRASE 76 80	SWEs
# T51	KEYPHRASE 490 493	UIM
# T53	KEYPHRASE 545 556	LISFLOOD-FP
# T57	KEYPHRASE 756 767	LISFLOOD-FP
# T70	KEYPHRASE 972 994	multi resolution grids
# T73	KEYPHRASE 137 143	models
# T81	KEYPHRASE 1124 1130	models
# T92	KEYPHRASE 1184 1207	optimisation techniques
# T117	KEYPHRASE 895 915	Cartesian directions
# T132	KEYPHRASE 51 74	Shallow Water Equations
# T133	KEYPHRASE 466 488	Urban Inundation Model
# T164	KEYPHRASE 1019 1032	InfoWorks ICM
# T199	KEYPHRASE 403 415	Yen and Tsai
#
#   +++ RAW +++
#
# T1	Process 51 74	Shallow Water Equations
# T2	Process 76 80	SWEs
# *	Synonym-of T1 T2
# T3	Process 269 273	SWEs
# T4	Process 428 433	JFLOW
# T5	Process 466 488	Urban Inundation Model
# T6	Process 490 493	UIM
# *	Synonym-of T5 T6
# T7	Process 545 556	LISFLOOD-FP
# T8	Process 756 767	LISFLOOD-FP
# T9	Process 800 804	SWEs
# T10	Process 854 865	LISFLOOD-FP
# T11	Process 895 915	Cartesian directions
# T12	Process 943 947	SWEs
# T13	Material 972 1012	multi resolution grids or irregular mesh
# T14	Material 1019 1032	InfoWorks ICM
# T15	Material 1054 1064	MIKE FLOOD
# R1	Hyponym-of Arg1:T14 Arg2:T13
# R2	Hyponym-of Arg1:T15 Arg2:T13
# T16	Process 238 273	reducing the complexity of the SWEs
# T17	Process 8 40	physically-based 2D flood models
# T18	Task 41 81	solve the Shallow Water Equations (SWEs)
# T19	Process 589 616	2D diffusion wave equations
#
#
# 10 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 70 91	di-cluster structures
# T2	KEYPHRASE 235 278	first-chance cluster breakup cross-sections
# T3	KEYPHRASE 318 345	xHe+A−xHe cluster structure
# T4	KEYPHRASE 421 443	decay energy threshold
# T5	KEYPHRASE 605 678	nuclei possess a stronger structural overlap with an α–Xn–α configuration
# T6	KEYPHRASE 693 711	reaction mechanics
# T7	KEYPHRASE 821 842	neutron rich isotopes
# T8	KEYPHRASE 915 941	comprehensive measurements
# T9	KEYPHRASE 949 984	neutron-removal and cluster breakup
# T10	KEYPHRASE 1012 1029	experimental data
# T11	KEYPHRASE 1064 1088	neutron-rich Be isotopes
#
#   +++ KLEIS +++
#
# T10	KEYPHRASE 125 140	breakup process
# T44	KEYPHRASE 693 701	reaction
# T47	KEYPHRASE 821 828	neutron
# T49	KEYPHRASE 969 976	cluster
# T70	KEYPHRASE 870 885	alpha-particles
# T75	KEYPHRASE 1114 1123	reactions
# T110	KEYPHRASE 1012 1029	experimental data
# T120	KEYPHRASE 821 842	neutron rich isotopes
#
#   +++ RAW +++
#
# T1	Process 421 433	decay energy
# T2	Process 544 566	breakup cross-sections
# T3	Material 870 885	alpha-particles
# T4	Material 891 907	valence neutrons
# T6	Task 915 984	comprehensive measurements of the neutron-removal and cluster breakup
# T7	Process 969 984	cluster breakup
# T8	Material 70 91	di-cluster structures
# T9	Process 125 140	breakup process
# T10	Process 173 229	wavefunctions of the ground state and the excited states
# T11	Process 235 278	first-chance cluster breakup cross-sections
# T12	Material 318 345	xHe+A−xHe cluster structure
# T13	Material 605 611	nuclei
# T14	Process 693 711	reaction mechanics
# T15	Material 821 842	neutron rich isotopes
# T16	Process 949 964	neutron-removal
# T5	Process 789 813	dominant structural mode
# T17	Material 1064 1088	neutron-rich Be isotopes
#
#
# 11 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 53 66	thorium metal
# T2	KEYPHRASE 88 105	elemental uranium
# T3	KEYPHRASE 126 143	uranium compounds
# T4	KEYPHRASE 172 195	uranium superconductors
# T5	KEYPHRASE 240 277	uranium heavy fermion superconductors
# T6	KEYPHRASE 348 390	discovery of ferromagnetic superconductors
# T7	KEYPHRASE 394 409	uranium systems
# T8	KEYPHRASE 620 641	Transuranium elements
# T9	KEYPHRASE 668 685	chemical elements
# T10	KEYPHRASE 816 834	synthetic elements
# T11	KEYPHRASE 921 936	latter elements
#
#   +++ KLEIS +++
#
# T9	KEYPHRASE 53 66	thorium metal
# T26	KEYPHRASE 444 461	superconductivity
# T27	KEYPHRASE 465 474	plutonium
# T30	KEYPHRASE 484 493	neptunium
# T35	KEYPHRASE 726 733	uranium
# T45	KEYPHRASE 585 589	N=89
# T49	KEYPHRASE 706 707	Z
# T50	KEYPHRASE 842 847	Z=103
# T63	KEYPHRASE 528 537	actinoids
# T65	KEYPHRASE 646 658	transuranics
# T69	KEYPHRASE 870 884	transactinides
# T70	KEYPHRASE 889 903	superactinides
# T76	KEYPHRASE 620 641	Transuranium elements
# T102	KEYPHRASE 172 195	uranium superconductors
# T105	KEYPHRASE 394 409	uranium systems
# T147	KEYPHRASE 159 195	new class of uranium superconductors
# T148	KEYPHRASE 804 834	essentially synthetic elements
# T177	KEYPHRASE 361 409	ferromagnetic superconductors in uranium systems
#
#   +++ RAW +++
#
# T1	Process 0 17	Superconductivity
# T2	Material 21 30	actinides
# T3	Task 0 30	Superconductivity in actinides
# T4	Material 53 66	thorium metal
# T5	Material 98 105	uranium
# T6	Material 126 143	uranium compounds
# T7	Material 172 195	uranium superconductors
# T8	Material 240 277	uranium heavy fermion superconductors
# T9	Material 361 390	ferromagnetic superconductors
# T10	Material 394 401	uranium
# T11	Material 465 474	plutonium
# T12	Process 444 461	superconductivity
# T13	Material 484 493	neptunium
# T14	Material 514 523	actinides
# T15	Process 569 583	periodic table
# T16	Material 620 641	Transuranium elements
# T17	Material 870 884	transactinides
# T18	Material 646 658	transuranics
# T19	Material 528 537	actinoids
# *	Synonym-of T14 T19
# *	Synonym-of T16 T18
# T20	Material 889 903	superactinides
# *	Synonym-of T17 T20
# R1	Hyponym-of Arg1:T4 Arg2:T2
# R2	Hyponym-of Arg1:T5 Arg2:T2
# R3	Hyponym-of Arg1:T6 Arg2:T2
# R4	Hyponym-of Arg1:T8 Arg2:T7
# T22	Material 591 593	Ac
# T23	Material 602 604	Th
# T24	Material 614 616	Lr
# R5	Hyponym-of Arg1:T22 Arg2:T19
# R6	Hyponym-of Arg1:T23 Arg2:T19
# R7	Hyponym-of Arg1:T24 Arg2:T19
# T25	Material 726 733	uranium
# T26	Material 816 834	synthetic elements
# T27	Material 849 851	Lr
# T21	Task 1018 1054	study of condensed-matter properties
#
#
# 12 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 37 86	photocatalytic activity are grafting co-catalysts
# T2	KEYPHRASE 175 184	electrons
# T3	KEYPHRASE 206 225	separation of holes
# T4	KEYPHRASE 231 265	former representative co-catalysts
# T5	KEYPHRASE 463 476	reduced metal
# T6	KEYPHRASE 496 508	reduced ions
# T7	KEYPHRASE 592 598	oxygen
# T8	KEYPHRASE 674 689	water oxidation
# T9	KEYPHRASE 761 776	water oxidation
# T10	KEYPHRASE 826 845	co-grafting effects
# T11	KEYPHRASE 974 983	electrons
# T12	KEYPHRASE 1118 1138	p-type semiconductor
# T13	KEYPHRASE 1161 1194	enhancing photocatalytic activity
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 463 476	reduced metal
# T4	KEYPHRASE 582 598	molecular oxygen
# T10	KEYPHRASE 1118 1138	p-type semiconductor
# T12	KEYPHRASE 674 689	water oxidation
# T13	KEYPHRASE 761 776	water oxidation
# T21	KEYPHRASE 364 371	cluster
# T23	KEYPHRASE 427 435	electron
# T26	KEYPHRASE 483 490	cluster
# T28	KEYPHRASE 570 578	electron
# T29	KEYPHRASE 592 598	oxygen
# T30	KEYPHRASE 674 679	water
# T31	KEYPHRASE 680 689	oxidation
# T32	KEYPHRASE 745 756	co-catalyst
# T33	KEYPHRASE 761 766	water
# T34	KEYPHRASE 767 776	oxidation
# T38	KEYPHRASE 922 933	co-grafting
# T45	KEYPHRASE 274 278	Fe3+
# T48	KEYPHRASE 318 322	Fe3+
# T49	KEYPHRASE 327 331	Cu2+
# T50	KEYPHRASE 397 401	Fe2+
# T54	KEYPHRASE 632 637	CoPOx
# T55	KEYPHRASE 640 644	IrOx
# T56	KEYPHRASE 650 654	RuOx
# T58	KEYPHRASE 1084 1089	BiVO4
# T62	KEYPHRASE 111 123	co-catalysts
# T64	KEYPHRASE 175 184	electrons
# T65	KEYPHRASE 220 225	holes
# T71	KEYPHRASE 942 954	co-catalysts
# T73	KEYPHRASE 974 983	electrons
# T74	KEYPHRASE 988 993	holes
# T108	KEYPHRASE 496 508	reduced ions
# T133	KEYPHRASE 231 265	former representative co-catalysts
#
#   +++ RAW +++
#
# T1	Task 22 60	enhancement of photocatalytic activity
# T2	Material 74 86	co-catalysts
# T3	Material 111 123	co-catalysts
# T4	Material 175 184	electrons
# T5	Material 220 225	holes
# T6	Material 270 272	Pt
# T7	Material 274 278	Fe3+
# T8	Material 284 288	Cu2+
# T9	Material 253 265	co-catalysts
# R1	Hyponym-of Arg1:T6 Arg2:T9
# R2	Hyponym-of Arg1:T7 Arg2:T9
# R3	Hyponym-of Arg1:T8 Arg2:T9
# T10	Material 318 322	Fe3+
# T11	Material 327 331	Cu2+
# T12	Material 397 401	Fe2+
# T13	Material 406 409	Cu+
# T14	Material 427 435	electron
# T15	Material 463 490	reduced metal oxide cluster
# T16	Material 496 508	reduced ions
# T17	Material 570 578	electron
# T18	Material 592 598	oxygen
# T19	Material 620 624	CoOx
# T20	Material 626 630	CoPi
# T21	Material 632 637	CoPOx
# *	Synonym-of T20 T21
# T22	Material 640 644	IrOx
# T23	Material 650 654	RuOx
# T24	Process 674 689	water oxidation
# T25	Material 703 707	CoPi
# T26	Material 745 756	co-catalyst
# T27	Process 761 776	water oxidation
# T28	Process 826 837	co-grafting
# T29	Process 849 872	photocatalytic activity
# T30	Process 922 933	co-grafting
# T31	Material 974 983	electrons
# T32	Material 988 993	holes
# T33	Process 995 1018	photocatalytic activity
# T34	Material 1084 1089	BiVO4
# T35	Material 1118 1138	p-type semiconductor
# T36	Process 1171 1194	photocatalytic activity
# T37	Material 348 371	amorphous oxide cluster
# R4	Hyponym-of Arg1:T25 Arg2:T26
# T38	Process 887 900	gaseous phase
# T39	Material 942 954	co-catalysts
# T40	Process 1022 1035	gaseous phase
# T41	Process 161 184	separation of electrons
# T42	Process 206 225	separation of holes
#
#
# 13 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 2 23	living polymerization
# T2	KEYPHRASE 59 80	termination reactions
# T3	KEYPHRASE 104 131	complete monomer conversion
# T4	KEYPHRASE 203 223	propagation reaction
# T5	KEYPHRASE 277 307	narrow molar mass distribution
# T6	KEYPHRASE 343 376	industrial styrene polymerization
# T7	KEYPHRASE 472 487	radical process
# T8	KEYPHRASE 491 543	remove residual monomer and low molar mass oligomers
# T9	KEYPHRASE 601 620	anionic polystyrene
# T10	KEYPHRASE 696 729	production of anionic polystyrene
# T11	KEYPHRASE 731 733	PS
# T12	KEYPHRASE 786 812	control the polymerization
# T13	KEYPHRASE 885 913	industrial radical processes
# T14	KEYPHRASE 926 942	organic solvents
# T15	KEYPHRASE 960 983	alkyllithium initiators
# T16	KEYPHRASE 1011 1036	low reaction temperatures
# T17	KEYPHRASE 1121 1168	quantitative living-like anionic polymerization
# T18	KEYPHRASE 1172 1179	styrene
# T19	KEYPHRASE 1241 1271	inexpensive initiating systems
# T20	KEYPHRASE 1347 1362	anionic process
#
#   +++ KLEIS +++
#
# T4	KEYPHRASE 472 487	radical process
# T9	KEYPHRASE 710 729	anionic polystyrene
# T15	KEYPHRASE 1347 1362	anionic process
# T17	KEYPHRASE 2 23	living polymerization
# T18	KEYPHRASE 203 223	propagation reaction
# T24	KEYPHRASE 29 37	reaction
# T25	KEYPHRASE 46 54	transfer
# T27	KEYPHRASE 121 131	conversion
# T29	KEYPHRASE 151 161	initiation
# T39	KEYPHRASE 417 424	washing
# T41	KEYPHRASE 507 514	monomer
# T43	KEYPHRASE 609 620	polystyrene
# T47	KEYPHRASE 718 729	polystyrene
# T49	KEYPHRASE 798 812	polymerization
# T56	KEYPHRASE 1172 1179	styrene
# T58	KEYPHRASE 1198 1205	solvent
# T62	KEYPHRASE 1401 1411	reactivity
# T64	KEYPHRASE 1429 1439	initiating
# T68	KEYPHRASE 731 733	PS
# T78	KEYPHRASE 225 233	polymers
# T82	KEYPHRASE 582 588	chains
# T145	KEYPHRASE 926 942	organic solvents
# T239	KEYPHRASE 113 131	monomer conversion
#
#   +++ RAW +++
#
# T1	Task 696 734	production of anionic polystyrene (PS)
# T2	Process 9 23	polymerization
# T3	Material 710 729	anionic polystyrene
# T4	Material 730 733	(PS
# *	Synonym-of T3 T4
# T5	Process 203 214	propagation
# T6	Task 343 376	industrial styrene polymerization
# T7	Process 960 983	alkyllithium initiators
# T8	Process 1146 1179	anionic polymerization of styrene
# T9	Material 1198 1205	solvent
# T10	Process 1444 1470	propagating active species
# T11	Material 601 620	anionic polystyrene
# T12	Process 59 70	termination
# T13	Process 113 131	monomer conversion
# T14	Material 225 233	polymers
# T15	Material 519 543	low molar mass oligomers
# T16	Process 798 812	polymerization
# T17	Process 417 424	washing
# T18	Process 428 437	degassing
# T19	Material 926 942	organic solvents
# T20	Process 29 37	reaction
# R1	Hyponym-of Arg1:T2 Arg2:T20
#
#
# 14 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 17 68	1D radial profiles obtained from circular averaging
# T2	KEYPHRASE 88 91	PSD
# T3	KEYPHRASE 151 169	circular averaging
# T4	KEYPHRASE 250 260	Thon rings
# T5	KEYPHRASE 337 390	algorithms that consider astigmatism involve concepts
# T6	KEYPHRASE 412 415	PSD
# T7	KEYPHRASE 435 445	Thon rings
# T8	KEYPHRASE 489 518	applying Canny edge detection
# T9	KEYPHRASE 551 571	elliptical averaging
# T10	KEYPHRASE 573 601	determining the relationship
# T11	KEYPHRASE 752 757	ATLAS
# T12	KEYPHRASE 790 815	estimating CTF parameters
# T13	KEYPHRASE 827 846	2D PSD optimization
# T14	KEYPHRASE 921 937	extensive search
# T15	KEYPHRASE 1031 1049	defocus estimation
# T16	KEYPHRASE 1061 1075	error analysis
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 151 169	circular averaging
# T5	KEYPHRASE 466 479	circular arcs
# T6	KEYPHRASE 551 571	elliptical averaging
# T12	KEYPHRASE 1031 1049	defocus estimation
# T13	KEYPHRASE 1061 1075	error analysis
# T18	KEYPHRASE 160 169	averaging
# T19	KEYPHRASE 190 201	astigmatism
# T33	KEYPHRASE 652 663	astigmatism
# T35	KEYPHRASE 703 711	database
# T49	KEYPHRASE 203 214	Astigmatism
# T51	KEYPHRASE 412 415	PSD
# T55	KEYPHRASE 752 757	ATLAS
# T64	KEYPHRASE 421 428	sectors
# T66	KEYPHRASE 531 536	rings
# T74	KEYPHRASE 250 260	Thon rings
# T75	KEYPHRASE 435 445	Thon rings
#
#   +++ RAW +++
#
# T1	Material 17 35	1D radial profiles
# T2	Process 50 68	circular averaging
# T3	Process 107 127	elliptical averaging
# T4	Process 151 169	circular averaging
# T5	Process 190 201	astigmatism
# T6	Process 203 214	Astigmatism
# T7	Material 250 260	Thon rings
# T8	Material 319 329	1D profile
# T9	Material 435 445	Thon rings
# T10	Process 498 518	Canny edge detection
# T11	Process 551 571	elliptical averaging
# T12	Process 652 663	astigmatism
# T13	Process 752 757	ATLAS
# T14	Process 827 846	2D PSD optimization
# T15	Process 801 804	CTF
# T16	Process 72 91	2D experimental PSD
# T17	Process 412 415	PSD
#
#
# 15 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 47 73	feature extraction methods
# T2	KEYPHRASE 126 130	SIFT
# T3	KEYPHRASE 157 183	Speeded up robust features
# T4	KEYPHRASE 188 192	SURF
# T5	KEYPHRASE 273 302	defined gestures of left hand
# T6	KEYPHRASE 332 355	Microsoft Kinect camera
# T7	KEYPHRASE 368 388	capturing the images
# T8	KEYPHRASE 398 420	Support vector machine
# T9	KEYPHRASE 425 428	SVM
# T10	KEYPHRASE 441 462	classification method
# T11	KEYPHRASE 492 525	SVM prediction on selected images
#
#   +++ KLEIS +++
#
# T8	KEYPHRASE 441 462	classification method
# T10	KEYPHRASE 16 26	comparison
# T24	KEYPHRASE 441 455	classification
# T33	KEYPHRASE 126 130	SIFT
# T35	KEYPHRASE 188 192	SURF
# T39	KEYPHRASE 425 428	SVM
# T47	KEYPHRASE 382 388	images
# T70	KEYPHRASE 398 420	Support vector machine
# T74	KEYPHRASE 510 525	selected images
# T75	KEYPHRASE 332 355	Microsoft Kinect camera
#
#   +++ RAW +++
#
# T1	Process 88 121	Scale-invariant feature transform
# T2	Process 126 130	SIFT
# T3	Process 157 183	Speeded up robust features
# T4	Process 188 192	SURF
# *	Synonym-of T1 T2
# *	Synonym-of T3 T4
# T5	Material 257 267	depth maps
# T6	Process 398 420	Support vector machine
# T7	Process 425 428	SVM
# *	Synonym-of T6 T7
# T8	Task 16 73	comparison between two popular feature extraction methods
# T9	Process 332 355	Microsoft Kinect camera
# T10	Process 492 495	SVM
# T22	Task 47 65	feature extraction
# T23	Process 441 455	classification
# T27	Process 441 462	classification method
# R2	Hyponym-of Arg1:T7 Arg2:T27
#
#
# 16 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 9 26	mean-field models
# T2	KEYPHRASE 65 80	little analysis
# T3	KEYPHRASE 127 153	extended dynamical systems
# T4	KEYPHRASE 212 223	Liley model
# T5	KEYPHRASE 281 325	coupled Partial Differential Equations (PDEs
# T6	KEYPHRASE 387 411	mean membrane potentials
# T7	KEYPHRASE 420 440	mean synaptic inputs
# T8	KEYPHRASE 482 519	Ordinary Differential Equations (ODEs
# T9	KEYPHRASE 551 572	homogeneous solutions
# T10	KEYPHRASE 633 663	numerical bifurcation analysis
# T11	KEYPHRASE 772 781	PDE model
# T12	KEYPHRASE 803 825	stable simulation code
# T13	KEYPHRASE 997 1014	iterative solvers
# T14	KEYPHRASE 1019 1034	linear problems
# T15	KEYPHRASE 1047 1062	sparse matrices
# T16	KEYPHRASE 1145 1167	software package PETSc
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 65 80	little analysis
# T18	KEYPHRASE 250 258	instance
# T23	KEYPHRASE 592 598	system
# T28	KEYPHRASE 719 729	equilibria
# T35	KEYPHRASE 904 910	domain
# T47	KEYPHRASE 633 663	numerical bifurcation analysis
# T50	KEYPHRASE 212 223	Liley model
# T51	KEYPHRASE 772 781	PDE model
# T56	KEYPHRASE 321 325	PDEs
# T59	KEYPHRASE 515 519	ODEs
# T66	KEYPHRASE 55 63	settings
# T79	KEYPHRASE 1217 1226	functions
# T115	KEYPHRASE 9 26	mean-field models
# T123	KEYPHRASE 1019 1034	linear problems
# T124	KEYPHRASE 1047 1062	sparse matrices
#
#   +++ RAW +++
#
# T1	Process 9 26	mean-field models
# T2	Task 117 153	spatially extended dynamical systems
# T3	Process 212 223	Liley model
# T4	Material 289 319	Partial Differential Equations
# T5	Material 392 411	membrane potentials
# T6	Material 425 440	synaptic inputs
# T7	Material 482 513	Ordinary Differential Equations
# T8	Material 321 325	PDEs
# T9	Material 515 519	ODEs
# *	Synonym-of T4 T8
# *	Synonym-of T7 T9
# T10	Process 633 663	numerical bifurcation analysis
# T11	Material 772 781	PDE model
# T12	Material 1040 1062	large, sparse matrices
# T13	Material 1162 1167	PETSc
# T14	Task 986 1062	efficient, iterative solvers for linear problems with large, sparse matrices
# T15	Process 986 1014	efficient, iterative solvers
#
#
# 17 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 31 35	FGMs
# T2	KEYPHRASE 101 163	heterogeneous composite materials exhibiting gradual variation
# T3	KEYPHRASE 335 363	Functionally Graded Material
# T4	KEYPHRASE 405 422	natural materials
# T5	KEYPHRASE 452 465	Study of bone
# T6	KEYPHRASE 690 718	Functionally Graded Material
# T7	KEYPHRASE 822 846	nuclear fission reactors
#
#   +++ KLEIS +++
#
# T13	KEYPHRASE 311 319	material
# T17	KEYPHRASE 461 465	bone
# T18	KEYPHRASE 467 472	shell
# T22	KEYPHRASE 562 569	outside
# T23	KEYPHRASE 599 609	protection
# T28	KEYPHRASE 801 804	use
# T32	KEYPHRASE 31 35	FGMs
# T84	KEYPHRASE 335 363	Functionally Graded Material
# T85	KEYPHRASE 690 718	Functionally Graded Material
# T86	KEYPHRASE 101 134	heterogeneous composite materials
# T144	KEYPHRASE 808 846	aerospace and nuclear fission reactors
#
#   +++ RAW +++
#
# T1	Material 0 29	Functionally Graded Materials
# T2	Task 452 494	Study of bone, shell, balsawood and bamboo
# T3	Material 690 718	Functionally Graded Material
# T4	Material 772 796	heat resistant materials
# T5	Task 808 817	aerospace
# T6	Task 822 846	nuclear fission reactors
# T7	Material 335 363	Functionally Graded Material
# T8	Material 31 35	FGMs
# *	Synonym-of T1 T8
# T9	Material 101 134	heterogeneous composite materials
# R1	Hyponym-of Arg1:T8 Arg2:T9
# T10	Material 488 494	bamboo
# T11	Material 474 483	balsawood
# T12	Material 467 472	shell
# T13	Material 461 465	bone
#
#
# 18 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 101 147	performance analysis of a blood-flow LB solver
# T2	KEYPHRASE 176 197	non-sparse geometries
# T3	KEYPHRASE 242 267	lattice-Boltzmann solvers
# T4	KEYPHRASE 394 417	decomposition technique
# T5	KEYPHRASE 431 474	real-time rendering and visualisation tasks
# T6	KEYPHRASE 486 500	LB simulations
# T7	KEYPHRASE 595 640	current performance characteristics of HemeLB
# T8	KEYPHRASE 836 868	coalesced communication patterns
# T9	KEYPHRASE 913 964	compile-time polymorphism to avoid virtual function
#
#   +++ KLEIS +++
#
# T16	KEYPHRASE 394 417	decomposition technique
# T25	KEYPHRASE 165 171	sparse
# T42	KEYPHRASE 711 715	code
# T47	KEYPHRASE 818 830	load-balance
# T51	KEYPHRASE 926 938	polymorphism
# T66	KEYPHRASE 574 580	HemeLB
# T67	KEYPHRASE 634 640	HemeLB
# T70	KEYPHRASE 836 868	coalesced communication patterns
# T81	KEYPHRASE 486 500	LB simulations
# T109	KEYPHRASE 242 267	lattice-Boltzmann solvers
# T175	KEYPHRASE 165 197	sparse and non-sparse geometries
#
#   +++ RAW +++
#
# T1	Process 127 147	blood-flow LB solver
# T2	Process 242 267	lattice-Boltzmann solvers
# T3	Process 209 237	performance prediction model
# T4	Process 341 359	HemeLB application
# T5	Process 370 376	HemeLB
# T6	Process 486 500	LB simulations
# T7	Process 574 580	HemeLB
# T8	Process 634 640	HemeLB
# T9	Material 794 802	ParMETIS
# T10	Process 913 938	compile-time polymorphism
# T11	Process 282 310	performance prediction model
# T12	Process 836 868	coalesced communication patterns
# T13	Process 895 904	rendering
# *	Synonym-of T4 T5
#
#
# 19 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 8 41	formulate the downscaling problem
# T2	KEYPHRASE 63 83	optimization problem
# T3	KEYPHRASE 247 276	appropriate scaling procedure
# T4	KEYPHRASE 500 529	appropriate scaling procedure
# T5	KEYPHRASE 736 757	multiple local minima
# T6	KEYPHRASE 898 920	Evolutionary Algorithm
# T7	KEYPHRASE 922 926	SPEA
# T8	KEYPHRASE 977 1019	single (weighted) fitness or cost function
# T9	KEYPHRASE 1036 1064	multi-objective optimization
# T10	KEYPHRASE 1070 1074	SPEA
# T11	KEYPHRASE 1094 1118	evolutionary computation
# T12	KEYPHRASE 1123 1151	SPEA the fitness calculation
# T13	KEYPHRASE 1163 1180	fitting procedure
# T14	KEYPHRASE 1248 1258	finite set
# T15	KEYPHRASE 1272 1293	Pareto optimal models
# T16	KEYPHRASE 1295 1312	downscaling rules
#
#   +++ KLEIS +++
#
# T10	KEYPHRASE 1163 1180	fitting procedure
# T18	KEYPHRASE 1006 1019	cost function
# T30	KEYPHRASE 431 440	objective
# T31	KEYPHRASE 469 479	regression
# T40	KEYPHRASE 771 783	optimization
# T43	KEYPHRASE 995 1002	fitness
# T47	KEYPHRASE 1107 1118	computation
# T60	KEYPHRASE 922 926	SPEA
# T64	KEYPHRASE 1070 1074	SPEA
# T68	KEYPHRASE 736 757	multiple local minima
# T70	KEYPHRASE 159 169	objectives
# T71	KEYPHRASE 216 221	units
# T73	KEYPHRASE 309 319	objectives
# T74	KEYPHRASE 616 626	objectives
# T78	KEYPHRASE 1229 1235	models
# T116	KEYPHRASE 1272 1293	Pareto optimal models
# T209	KEYPHRASE 882 920	Strength Pareto Evolutionary Algorithm
#
#   +++ RAW +++
#
# T1	Process 47 75	multi-objective optimization
# T2	Process 259 276	scaling procedure
# T3	Process 512 529	scaling procedure
# T4	Process 771 783	optimization
# T5	Process 882 920	Strength Pareto Evolutionary Algorithm
# T6	Process 922 926	SPEA
# *	Synonym-of T5 T6
# T7	Process 1036 1064	multi-objective optimization
# T8	Process 1070 1074	SPEA
# T9	Task 1094 1118	evolutionary computation
# T10	Process 1123 1127	SPEA
# T11	Process 1272 1293	Pareto optimal models
# R1	Hyponym-of Arg1:T8 Arg2:T7
# T12	Process 1295 1312	downscaling rules
# *	Synonym-of T11 T12
# T13	Process 469 479	regression
# T14	Process 969 1019	using a single (weighted) fitness or cost function
# T15	Process 1132 1151	fitness calculation
#
#
# 20 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 0 20	Numerical simulation
# T2	KEYPHRASE 28 36	gas flow
# T3	KEYPHRASE 134 171	conventional continuum fluid dynamics
# T4	KEYPHRASE 202 205	gas
# T5	KEYPHRASE 229 254	thermodynamic equilibrium
# T6	KEYPHRASE 402 422	molecular collisions
# T7	KEYPHRASE 456 477	modelling alternative
# T8	KEYPHRASE 501 537	direct simulation Monte Carlo method
# T9	KEYPHRASE 539 543	DSMC
# T10	KEYPHRASE 559 563	DSMC
# T11	KEYPHRASE 1017 1032	channel network
#
#   +++ KLEIS +++
#
# T1	KEYPHRASE 0 20	Numerical simulation
# T3	KEYPHRASE 229 254	thermodynamic equilibrium
# T14	KEYPHRASE 28 36	gas flow
# T22	KEYPHRASE 28 31	gas
# T26	KEYPHRASE 202 205	gas
# T35	KEYPHRASE 434 442	accurate
# T43	KEYPHRASE 724 737	cross-section
# T64	KEYPHRASE 539 543	DSMC
# T65	KEYPHRASE 559 563	DSMC
# T102	KEYPHRASE 402 422	molecular collisions
# T122	KEYPHRASE 134 171	conventional continuum fluid dynamics
# T161	KEYPHRASE 0 36	Numerical simulation of the gas flow
#
#   +++ RAW +++
#
# T1	Task 0 20	Numerical simulation
# T2	Process 28 36	gas flow
# T3	Process 134 171	conventional continuum fluid dynamics
# T4	Process 229 254	thermodynamic equilibrium
# T5	Material 349 363	channel height
# T6	Process 501 537	direct simulation Monte Carlo method
# T7	Process 539 543	DSMC
# T8	Process 559 563	DSMC
# *	Synonym-of T6 T7
# T9	Process 599 625	internal-flow applications
# T10	Material 662 679	high-aspect ratio
# T11	Material 744 761	high-aspect ratio
# T14	Process 434 477	accurate and flexible modelling alternative
# T15	Process 402 422	molecular collisions
# R1	Hyponym-of Arg1:T6 Arg2:T14
# T16	Process 1012 1032	long channel network
# T17	Task 783 801	multiscale problem
#
#
# 21 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 27	Discrete Element Method
# T2	KEYPHRASE 83 97	realistic tool
# T3	KEYPHRASE 147 195	modelling packing and flow of granular materials
# T4	KEYPHRASE 412 443	explicit time stepping approach
# T5	KEYPHRASE 491 508	rotational motion
# T6	KEYPHRASE 620 642	particle wall contacts
# T7	KEYPHRASE 666 702	linear spring–dashpot–slider analogy
# T8	KEYPHRASE 792 829	line connecting the particles centres
# T9	KEYPHRASE 831 857	Particle elastic stiffness
# T10	KEYPHRASE 875 884	“overlap”
# T11	KEYPHRASE 908 932	moderate contact damping
# T12	KEYPHRASE 1060 1077	rotational motion
# T13	KEYPHRASE 1115 1170	half step leap-frog Verlet numerical integration scheme
# T14	KEYPHRASE 1174 1199	update particle positions
# T15	KEYPHRASE 1290 1319	determining particle contacts
# T16	KEYPHRASE 1326 1339	zoning method
# T17	KEYPHRASE 1415 1428	cubic regions
# T18	KEYPHRASE 1435 1450	particle centre
# T19	KEYPHRASE 1485 1505	contacting particles
#
#   +++ KLEIS +++
#
# T20	KEYPHRASE 1435 1450	particle centre
# T24	KEYPHRASE 157 164	packing
# T29	KEYPHRASE 270 274	code
# T30	KEYPHRASE 285 293	in-house
# T31	KEYPHRASE 389 396	summary
# T35	KEYPHRASE 517 525	particle
# T36	KEYPHRASE 587 595	timestep
# T37	KEYPHRASE 601 615	inter-particle
# T38	KEYPHRASE 620 628	particle
# T44	KEYPHRASE 792 796	line
# T50	KEYPHRASE 954 962	cohesion
# T53	KEYPHRASE 1086 1094	particle
# T57	KEYPHRASE 1181 1189	particle
# T59	KEYPHRASE 1302 1310	particle
# T63	KEYPHRASE 1362 1366	list
# T64	KEYPHRASE 1392 1398	system
# T65	KEYPHRASE 1435 1443	particle
# T67	KEYPHRASE 1465 1469	zone
# T80	KEYPHRASE 831 839	Particle
# T86	KEYPHRASE 39 46	spheres
# T90	KEYPHRASE 347 354	details
# T91	KEYPHRASE 545 551	forces
# T99	KEYPHRASE 1204 1214	velocities
# T195	KEYPHRASE 4 27	Discrete Element Method
# T255	KEYPHRASE 831 857	Particle elastic stiffness
#
#   +++ RAW +++
#
# T1	Process 4 27	Discrete Element Method
# T2	Material 39 46	spheres
# T3	Material 177 195	granular materials
# T4	Process 412 443	explicit time stepping approach
# T5	Process 473 508	translational and rotational motion
# T6	Process 545 551	forces
# T7	Process 666 702	linear spring–dashpot–slider analogy
# T8	Process 945 962	Particle cohesion
# T9	Process 1042 1077	translational and rotational motion
# T10	Process 1115 1170	half step leap-frog Verlet numerical integration scheme
# T11	Material 1181 1199	particle positions
# T12	Material 1204 1214	velocities
# T13	Task 147 195	modelling packing and flow of granular materials
# T14	Process 1216 1236	Near-neighbour lists
# T16	Process 556 563	moments
# T17	Process 447 468	numerically integrate
# T18	Material 601 642	inter-particle and particle wall contacts
# T19	Process 704 718	Contact forces
# T20	Material 812 829	particles centres
# T21	Process 831 857	Particle elastic stiffness
# T22	Material 831 847	Particle elastic
# T23	Process 868 884	sphere “overlap”
# T24	Process 917 932	contact damping
# T25	Material 1086 1094	particle
# T26	Material 1302 1319	particle contacts
# T27	Process 1326 1339	zoning method
# T15	Material 1435 1450	particle centre
# T28	Material 1485 1505	contacting particles
# T29	Material 868 874	sphere
#
#
# 22 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 59 80	friction coefficients
# ...
# T12	KEYPHRASE 831 852	interacting variables
# T13	KEYPHRASE 880 901	measured N2O datasets
# T14	KEYPHRASE 966 1006	soil N content) cover small time periods
# T15	KEYPHRASE 1123 1137	simulated data
# T16	KEYPHRASE 1187 1217	soil mineral N (second example
# T17	KEYPHRASE 1341 1355	N2O prediction
# T18	KEYPHRASE 1489 1503	N2O prediction
# T19	KEYPHRASE 1534 1577	soil moisture and soil mineral N prediction
# T20	KEYPHRASE 1601 1622	positive relationship
#
#   +++ KLEIS +++
#
# T11	KEYPHRASE 1601 1622	positive relationship
# T26	KEYPHRASE 157 168	correlation
# T31	KEYPHRASE 363 374	correlation
# T39	KEYPHRASE 632 640	relation
# T50	KEYPHRASE 1055 1059	size
# T52	KEYPHRASE 1094 1103	algorithm
# T60	KEYPHRASE 1375 1379	lags
# T77	KEYPHRASE 1341 1355	N2O prediction
# T78	KEYPHRASE 1489 1503	N2O prediction
# T80	KEYPHRASE 49 51	UK
# T81	KEYPHRASE 283 286	MSE
# T82	KEYPHRASE 320 322	SB
# T83	KEYPHRASE 324 328	SDSD
# T84	KEYPHRASE 333 336	LCS
# T89	KEYPHRASE 1277 1280	N2O
# T96	KEYPHRASE 71 75	lags
# T99	KEYPHRASE 242 251	residuals
# T101	KEYPHRASE 397 406	residuals
# T104	KEYPHRASE 531 535	lags
# T123	KEYPHRASE 889 901	N2O datasets
# T164	KEYPHRASE 910 927	measured datasets
# T198	KEYPHRASE 190 204	simulated data
# T199	KEYPHRASE 1123 1137	simulated data
# T264	KEYPHRASE 675 695	simulated daily data
# T265	KEYPHRASE 324 336	SDSD and LCS
#
#   +++ RAW +++
#
# T1	Task 107 123	model evaluation
# T2	Process 296 318	constituent statistics
# T3	Process 320 322	SB
# R1	Hyponym-of Arg1:T3 Arg2:T2
# T4	Material 790 803	N2O emissions
# T5	Material 889 901	N2O datasets
# T6	Process 283 286	MSE
# T7	Process 324 328	SDSD
# T8	Process 333 336	LCS
# R2	Hyponym-of Arg1:T7 Arg2:T2
# R3	Hyponym-of Arg1:T8 Arg2:T2
# T9	Material 1277 1280	N2O
# T10	Task 1489 1503	N2O prediction
# T11	Task 1341 1355	N2O prediction
# T13	Material 1110 1155	measured and simulated data for soil moisture
# T14	Material 1187 1201	soil mineral N
# T12	Material 1341 1344	N2O
# T15	Task 1383 1407	soil moisture prediction
# T16	Material 1534 1547	soil moisture
# T17	Task 1552 1577	soil mineral N prediction
# T18	Material 1552 1566	soil mineral N
#
#
# 94 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 114 143	two-loop QED effective action
# T2	KEYPHRASE 203 218	one-loop action
# T3	KEYPHRASE 384 428	all-loop effective action for gauge theories
# T4	KEYPHRASE 520 546	relaxed super self-duality
# T5	KEYPHRASE 693 718	N=2 covariant supergraphs
# T6	KEYPHRASE 856 908	D3-brane action in AdS5×S5 and the low-energy action
# T7	KEYPHRASE 913 948	N=4 SU(N) SYM on its Coulomb branch
# T8	KEYPHRASE 959 1010	gauge group SU(N) spontaneously broken to SU(N−1)×U
# T9	KEYPHRASE 1051 1059	F6 tests
#
#   +++ KLEIS +++
#
# T20	KEYPHRASE 137 143	action
# T23	KEYPHRASE 231 241	background
# T31	KEYPHRASE 496 508	self-duality
# T65	KEYPHRASE 923 926	SYM
# T69	KEYPHRASE 1001 1003	SU
# T70	KEYPHRASE 1004 1007	N−1
# T172	KEYPHRASE 913 919	N=4 SU
#
#   +++ RAW +++
#
# T1	Material 114 126	two-loop QED
# T2	Process 114 143	two-loop QED effective action
# T3	Process 203 218	one-loop action
# T4	Process 299 311	higher loops
# T5	Process 384 409	all-loop effective action
# T6	Task 681 718	analysis of N=2 covariant supergraphs
# T7	Material 697 718	covariant supergraphs
# T8	Process 856 871	D3-brane action
# T9	Material 875 882	AdS5×S5
# T10	Material 934 948	Coulomb branch
# T11	Material 959 970	gauge group
# T12	Material 971 976	SU(N)
# R1	Hyponym-of Arg1:T12 Arg2:T11
# T13	Material 1001 1013	SU(N−1)×U(1)
# T14	Material 917 926	SU(N) SYM
# T15	Task 1051 1078	F6 tests of this conjecture
#
#
# 95 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 38 119	LBP (local binary pattern) based fast face recognition system on symbian platform
# T2	KEYPHRASE 193 211	AdaBoost algorithm
# T3	KEYPHRASE 271 283	eye location
# T4	KEYPHRASE 285 308	geometric normalization
# T5	KEYPHRASE 310 336	illumination normalization
# T6	KEYPHRASE 349 367	face preprocessing
# T7	KEYPHRASE 371 396	rapid eye location method
# T8	KEYPHRASE 403 405	ER
# T9	KEYPHRASE 407 421	Eyeball Search
# T10	KEYPHRASE 471 474	LBP
# T11	KEYPHRASE 548 564	symbian platform
# T12	KEYPHRASE 701 782	LBP (local binary pattern) based fast face recognition system on symbian platform
# T13	KEYPHRASE 856 874	AdaBoost algorithm
# T14	KEYPHRASE 934 946	eye location
# T15	KEYPHRASE 948 971	geometric normalization
# T16	KEYPHRASE 973 999	illumination normalization
# T17	KEYPHRASE 1012 1030	face preprocessing
# T18	KEYPHRASE 1034 1059	rapid eye location method
# T19	KEYPHRASE 1066 1068	ER
# T20	KEYPHRASE 1070 1084	Eyeball Search
# T21	KEYPHRASE 1134 1137	LBP
# T22	KEYPHRASE 1211 1227	symbian platform
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 103 119	symbian platform
# T3	KEYPHRASE 285 308	geometric normalization
# T6	KEYPHRASE 548 564	symbian platform
# T9	KEYPHRASE 766 782	symbian platform
# T10	KEYPHRASE 948 971	geometric normalization
# T13	KEYPHRASE 1211 1227	symbian platform
# T18	KEYPHRASE 271 283	eye location
# T19	KEYPHRASE 310 336	illumination normalization
# T20	KEYPHRASE 349 367	face preprocessing
# T27	KEYPHRASE 934 946	eye location
# T28	KEYPHRASE 973 999	illumination normalization
# T29	KEYPHRASE 1012 1030	face preprocessing
# T43	KEYPHRASE 141 145	face
# T45	KEYPHRASE 168 174	camera
# T48	KEYPHRASE 247 251	face
# T59	KEYPHRASE 490 501	recognition
# T63	KEYPHRASE 628 639	recognition
# T75	KEYPHRASE 804 808	face
# T77	KEYPHRASE 831 837	camera
# T80	KEYPHRASE 910 914	face
# T91	KEYPHRASE 1153 1164	recognition
# T95	KEYPHRASE 1291 1302	recognition
# T107	KEYPHRASE 193 211	AdaBoost algorithm
# T108	KEYPHRASE 856 874	AdaBoost algorithm
# T109	KEYPHRASE 38 41	LBP
# T116	KEYPHRASE 471 474	LBP
# T117	KEYPHRASE 701 704	LBP
# T124	KEYPHRASE 1134 1137	LBP
# T127	KEYPHRASE 371 396	rapid eye location method
# T128	KEYPHRASE 1034 1059	rapid eye location method
#
#   +++ RAW +++
#
# T1	Material 38 41	LBP
# T2	Material 43 63	local binary pattern
# *	Synonym-of T1 T2
# T3	Task 271 336	eye location, geometric normalization, illumination normalization
# T4	Process 403 405	ER
# T5	Process 407 421	Eyeball Search
# T6	Process 377 396	eye location method
# *	Synonym-of T5 T4
# R1	Hyponym-of Arg1:T4 Arg2:T6
# T7	Material 471 474	LBP
# T8	Material 701 704	LBP
# T9	Material 706 726	local binary pattern
# *	Synonym-of T8 T9
# T10	Task 934 946	eye location
# T11	Process 1040 1059	eye location method
# T12	Process 1066 1068	ER
# T13	Process 1070 1084	Eyeball Search
# *	Synonym-of T13 T12
# R2	Hyponym-of Arg1:T12 Arg2:T11
# T14	Material 1134 1137	LBP
# T15	Task 490 501	recognition
# T16	Process 1153 1164	recognition
# T17	Task 1291 1302	recognition
# T18	Process 193 211	AdaBoost algorithm
# T19	Process 1017 1030	preprocessing
# T20	Process 856 874	AdaBoost algorithm
# T21	Material 548 564	symbian platform
# T22	Material 766 782	symbian platform
# T23	Task 888 914	pre-processing of the face
# T24	Task 948 971	geometric normalization
# T25	Task 973 999	illumination normalization
# R3	Hyponym-of Arg1:T10 Arg2:T23
# R4	Hyponym-of Arg1:T24 Arg2:T23
# R5	Hyponym-of Arg1:T25 Arg2:T23
# T26	Material 1211 1227	symbian platform
# T27	Material 76 99	face recognition system
# T28	Task 76 92	face recognition
# T29	Material 103 119	symbian platform
# T30	Task 349 367	face preprocessing
# T31	Task 377 389	eye location
# R6	Hyponym-of Arg1:T31 Arg2:T30
#
#
# 96 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 33	first-principles calculations
# T2	KEYPHRASE 58 95	Cambridge Serial Total Energy Package
# T3	KEYPHRASE 97 103	CASTEP
# T4	KEYPHRASE 131 168	plane-wave pseudopotential DFT method
# T5	KEYPHRASE 174 205	exchange correlation functional
# T6	KEYPHRASE 232 266	generalized gradient approximation
# T7	KEYPHRASE 268 275	PBE-GGA
# T8	KEYPHRASE 291 316	electron–ion interactions
# T9	KEYPHRASE 334 376	Vanderbilt-type ultrasoft pseudopotentials
# T10	KEYPHRASE 387 407	plane wave basis set
# T11	KEYPHRASE 451 474	Brillouin-zone sampling
# T12	KEYPHRASE 499 520	Monkhorst-Pack scheme
# T13	KEYPHRASE 528 581	k-point spacing in reciprocal space of 0.04Å−1. Tests
# T14	KEYPHRASE 693 707	ferromagnetism
# T15	KEYPHRASE 805 861	ferromagnetic initial configuration and relaxing towards
# T16	KEYPHRASE 926 973	ground state electronic structure of each alloy
# T17	KEYPHRASE 1009 1023	ferromagnetism
# T18	KEYPHRASE 1120 1149	equilibrium lattice constants
# T19	KEYPHRASE 1176 1178	Ti
# T20	KEYPHRASE 1211 1232	ordered ηP structures
# T21	KEYPHRASE 1270 1272	Ti
# T22	KEYPHRASE 1360 1362	Ti
# T23	KEYPHRASE 1368 1396	calculated lattice constants
# T24	KEYPHRASE 1481 1486	Al/Ti
#
#   +++ KLEIS +++
#
# T2	KEYPHRASE 499 520	Monkhorst-Pack scheme
# T5	KEYPHRASE 772 789	spin polarization
# T32	KEYPHRASE 387 392	plane
# T40	KEYPHRASE 693 707	ferromagnetism
# T41	KEYPHRASE 711 717	nickel
# T50	KEYPHRASE 968 973	alloy
# T51	KEYPHRASE 1009 1023	ferromagnetism
# T66	KEYPHRASE 1496 1501	∼2.75
# T67	KEYPHRASE 232 266	generalized gradient approximation
# T71	KEYPHRASE 451 474	Brillouin-zone sampling
# T79	KEYPHRASE 97 103	CASTEP
# T81	KEYPHRASE 268 275	PBE-GGA
# T85	KEYPHRASE 1270 1272	Ti
# T87	KEYPHRASE 1360 1362	Ti
# T89	KEYPHRASE 1368 1396	calculated lattice constants
# T108	KEYPHRASE 1270 1281	Ti alloying
# T117	KEYPHRASE 291 316	electron–ion interactions
# T151	KEYPHRASE 334 376	Vanderbilt-type ultrasoft pseudopotentials
#
#   +++ RAW +++
#
# T1	Task 4 33	first-principles calculations
# T2	Material 58 95	Cambridge Serial Total Energy Package
# T3	Process 131 168	plane-wave pseudopotential DFT method
# T4	Material 97 103	CASTEP
# *	Synonym-of T2 T4
# T5	Process 232 266	generalized gradient approximation
# T6	Process 291 316	electron–ion interactions
# T7	Process 334 376	Vanderbilt-type ultrasoft pseudopotentials
# T8	Process 451 474	Brillouin-zone sampling
# T9	Process 499 520	Monkhorst-Pack scheme
# T10	Material 711 717	nickel
# T11	Process 1009 1023	ferromagnetism
# T12	Process 693 707	ferromagnetism
# T13	Material 1219 1232	ηP structures
# T14	Material 1468 1473	alloy
# T15	Process 174 205	exchange correlation functional
# T16	Process 268 275	PBE-GGA
# *	Synonym-of T5 T16
# T17	Material 291 299	electron
# T18	Material 300 303	ion
# T19	Material 387 397	plane wave
# T20	Process 528 543	k-point spacing
# T21	Process 772 789	spin polarization
# T22	Material 968 973	alloy
# T23	Material 1176 1178	Ti
# T24	Process 1270 1281	Ti alloying
# T25	Material 1270 1272	Ti
# T26	Material 1360 1362	Ti
# T27	Material 1481 1483	Al
# T28	Material 1484 1486	Ti
#
#
# 97 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 3 55	obvious metric to measure the monitoring performance
# T2	KEYPHRASE 203 242	buffer values of the respective buffers
# T3	KEYPHRASE 800 818	signal interaction
# T4	KEYPHRASE 961 981	respective condition
#
#   +++ KLEIS +++
#
# T20	KEYPHRASE 160 169	condition
# T22	KEYPHRASE 186 194	interest
# T26	KEYPHRASE 269 280	interaction
# T27	KEYPHRASE 290 300	simulation
# T30	KEYPHRASE 338 345	machine
# T38	KEYPHRASE 528 539	interaction
# T53	KEYPHRASE 921 933	intervention
# T59	KEYPHRASE 1327 1334	account
# T60	KEYPHRASE 800 824	signal interaction needs
# T62	KEYPHRASE 78 88	conditions
# T68	KEYPHRASE 633 642	intervals
# T73	KEYPHRASE 1007 1012	users
# T79	KEYPHRASE 1241 1247	clicks
#
#   +++ RAW +++
#
# T1	Task 101 169	compare how many clicks the users made in average for each condition
# T2	Material 235 242	buffers
# T3	Material 700 706	buffer
# T4	Material 862 868	buffer
# T5	Material 203 209	buffer
# T6	Material 312 324	input buffer
# T7	Process 290 300	simulation
#
#
# 98 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 35 50	FIB instruments
# T2	KEYPHRASE 56 92	gallium (Ga) liquid metal ion source
# T3	KEYPHRASE 94 98	LMIS
# T4	KEYPHRASE 194 223	standard atmospheric pressure
# T5	KEYPHRASE 305 316	Ga ion beam
# T6	KEYPHRASE 381 431	chemical composition of the starting material upon
# T7	KEYPHRASE 448 459	Ga ion beam
# T8	KEYPHRASE 465 500	Group III–V compound semiconductors
# T9	KEYPHRASE 556 572	Cryo-FIB milling
# T10	KEYPHRASE 638 669	Ga ion beam and III–V materials
# T11	KEYPHRASE 679 773	suggested advantage of cryo-FIB milling over room temperature milling of Group III–V materials
# T12	KEYPHRASE 881 911	electronic or photonic devices
# T13	KEYPHRASE 922 1033	favorable electron transport and direct band gap properties associated with several III–V semiconductor systems
#
#   +++ KLEIS +++
#
# T7	KEYPHRASE 702 718	cryo-FIB milling
# T29	KEYPHRASE 56 63	gallium
# T30	KEYPHRASE 69 75	liquid
# T47	KEYPHRASE 367 376	structure
# T68	KEYPHRASE 872 876	e.g.
# T84	KEYPHRASE 556 572	Cryo-FIB milling
# T89	KEYPHRASE 94 98	LMIS
# T90	KEYPHRASE 105 112	Gallium
# T106	KEYPHRASE 352 359	changes
# T109	KEYPHRASE 616 625	reactions
# T117	KEYPHRASE 35 50	FIB instruments
# T144	KEYPHRASE 895 911	photonic devices
# T153	KEYPHRASE 1006 1033	III–V semiconductor systems
# T154	KEYPHRASE 305 316	Ga ion beam
# T155	KEYPHRASE 448 459	Ga ion beam
# T156	KEYPHRASE 638 649	Ga ion beam
# T168	KEYPHRASE 881 911	electronic or photonic devices
# T210	KEYPHRASE 752 773	Group III–V materials
#
#   +++ RAW +++
#
# T1	Process 35 50	FIB instruments
# T2	Material 56 63	gallium
# T3	Material 65 67	Ga
# *	Synonym-of T2 T3
# T4	Process 305 316	Ga ion beam
# T5	Process 448 459	Ga ion beam
# T6	Process 486 500	semiconductors
# T7	Task 556 572	Cryo-FIB milling
# T8	Process 638 649	Ga ion beam
# T9	Material 654 669	III–V materials
# T10	Task 702 718	cryo-FIB milling
# T11	Material 752 773	Group III–V materials
# T12	Process 1012 1025	semiconductor
# T13	Material 105 112	Gallium
# T14	Process 881 910	electronic or photonic device
#
#
# 99 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 4 46	threshold values for removing large caters
# T2	KEYPHRASE 407 478	minimize the distortion resulted from map projection on global datasets
# T3	KEYPHRASE 498 519	equal area projection
# T4	KEYPHRASE 586 619	conduct geodesic area calculation
# T5	KEYPHRASE 654 680	Graphics and Shapes” (http
# T6	KEYPHRASE 755 782	modification to the valleys
# T7	KEYPHRASE 876 904	eolian fill and mass wasting
# T8	KEYPHRASE 972 983	PBTH method
# T9	KEYPHRASE 1039 1084	MOLA and HRSC data reveals that MOLA estimate
# T10	KEYPHRASE 1101 1105	HRSC
# T11	KEYPHRASE 1122 1126	MOLA
# T12	KEYPHRASE 1131 1164	global coverage whereas HRSC does
# T13	KEYPHRASE 1211 1224	MOLA coverage
# T14	KEYPHRASE 1307 1311	DEMs
# T15	KEYPHRASE 1346 1359	simulated DEM
# T16	KEYPHRASE 1369 1373	HRSC
# T17	KEYPHRASE 1388 1392	MOLA
# T18	KEYPHRASE 1444 1448	DEMs
#
#   +++ KLEIS +++
#
# T6	KEYPHRASE 876 887	eolian fill
# T16	KEYPHRASE 189 194	error
# T20	KEYPHRASE 323 330	editing
# T21	KEYPHRASE 420 430	distortion
# T37	KEYPHRASE 906 910	e.g.
# T48	KEYPHRASE 1230 1238	estimate
# T49	KEYPHRASE 1278 1287	algorithm
# T54	KEYPHRASE 972 983	PBTH method
# T56	KEYPHRASE 1071 1084	MOLA estimate
# T57	KEYPHRASE 1101 1111	HRSC value
# T58	KEYPHRASE 1211 1224	MOLA coverage
# T70	KEYPHRASE 972 976	PBTH
# T71	KEYPHRASE 1039 1043	MOLA
# T75	KEYPHRASE 1122 1126	MOLA
# T78	KEYPHRASE 1307 1311	DEMs
# T80	KEYPHRASE 1369 1373	HRSC
# T81	KEYPHRASE 1388 1392	MOLA
# T84	KEYPHRASE 308 330	minimum manual editing
# T87	KEYPHRASE 80 87	craters
# T93	KEYPHRASE 775 782	valleys
# T94	KEYPHRASE 854 867	modifications
# T97	KEYPHRASE 1185 1190	areas
# T136	KEYPHRASE 463 478	global datasets
# T171	KEYPHRASE 1346 1359	simulated DEM
# T239	KEYPHRASE 654 673	Graphics and Shapes
#
#   +++ RAW +++
#
# T1	Process 316 330	manual editing
# T2	Task 0 62	The threshold values for removing large caters were determined
# T3	Process 644 673	Tools for Graphics and Shapes
# T4	Material 1039 1043	MOLA
# T5	Material 1122 1126	MOLA
# T6	Material 1211 1215	MOLA
# T7	Material 1307 1311	DEMs
# T8	Material 1444 1448	DEMs
# T9	Process 972 983	PBTH method
# T10	Material 1071 1075	MOLA
# T11	Material 1101 1105	HRSC
# T12	Material 1356 1359	DEM
# T13	Material 1048 1052	HRSC
# T14	Material 1155 1159	HRSC
# T15	Material 1369 1373	HRSC
# T16	Material 1388 1392	MOLA
#
#
# 100 ----
#
#   +++ CRF +++
#
# T1	KEYPHRASE 16 67	multispecies model of Calogero type in D dimensions
# T2	KEYPHRASE 152 154	SU
# T3	KEYPHRASE 227 246	Bargmann–Fock space
# T4	KEYPHRASE 281 307	equidistant energy spectra
# T5	KEYPHRASE 413 436	global dilatation modes
# T6	KEYPHRASE 577 587	Fock space
# T7	KEYPHRASE 749 751	SU
#
#   +++ KLEIS +++
#
# T10	KEYPHRASE 160 167	algebra
# T15	KEYPHRASE 316 321	tower
# T26	KEYPHRASE 227 246	Bargmann–Fock space
# T27	KEYPHRASE 577 587	Fock space
# T51	KEYPHRASE 55 67	D dimensions
#
#   +++ RAW +++
#
# T1	Process 16 34	multispecies model
# T2	Process 73 119	harmonic, two-body and three-body interactions
# T3	Task 3 67	define a new multispecies model of Calogero type in D dimensions
# T4	Process 142 167	conformal SU(1,1) algebra
# T6	Process 281 307	equidistant energy spectra
# T7	Process 490 516	construct ladder operators
# T8	Process 442 480	find their corresponding eigenenergies
# T9	Process 338 374	construct all polynomial eigenstates
# T10	Task 553 587	Analysing corresponding Fock space
